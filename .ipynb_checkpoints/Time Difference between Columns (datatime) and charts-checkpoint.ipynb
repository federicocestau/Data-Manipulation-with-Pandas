# %%
table['InvoiceDate2'] = table['InvoiceDate'].diff().apply(lambda x: x/np.timedelta64(1, 'm')).fillna(0).astype('int64')

# %%
#checking the difference in time between two columns. 
table.loc[table['InvoiceDate2'] != 0 ]
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 7         536366     22633               HAND WARMER UNION JACK         6
# 9         536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
# 25        536369     21756             BATH BUILDING BLOCK WORD         3
# 26        536370     22728            ALARM CLOCK BAKELIKE PINK        24
# 46        536371     22086      PAPER CHAIN KIT 50'S CHRISTMAS         80
# ...          ...       ...                                  ...       ...
# 541865    581583     20725              LUNCH BAG RED RETROSPOT        40
# 541867    581584     20832     RED FLOCK LOVE HEART PHOTO FRAME        72
# 541869    581585     22481       BLACK TEA TOWEL CLASSIC DESIGN        12
# 541890    581586     22061  LARGE CAKE STAND  HANGING STRAWBERY         8
# 541894    581587     22631             CIRCUS PARADE LUNCH BOX         12
#
#                InvoiceDate  UnitPrice  CustomerID         Country  \
# ...

# %%
table.loc[(table['Quantity'] >= 10) & (table['Quantity'] <= 200)].sort_values(by=['Quantity'])
# Out:
#        InvoiceNo StockCode                     Description  Quantity  \
# 212421    555477     23202          JUMBO BAG VINTAGE LEAF        10
# 269546    560454     23206          LUNCH BAG APPLE DESIGN        10
# 525324    580615     23344       JUMBO BAG 50'S CHRISTMAS         10
# 269545    560454     20728             LUNCH BAG CARS BLUE        10
# 269544    560454     23209       LUNCH BAG DOILEY PATTERN         10
# ...          ...       ...                             ...       ...
# 299022    563076     23346                 SPACEBOY BEAKER       200
# 115973    546169     15036       ASSORTED COLOURS SILK FAN       200
# 92225     544183     22148          EASTER CRAFT 4 CHICKS        200
# 115974    546169     21112    SWISS ROLL TOWEL PINK  SPOTS       200
# 32662     539101     22780  LIGHT GARLAND BUTTERFILES PINK       200
#
#                InvoiceDate  UnitPrice  CustomerID         Country  \
# 212421 2011-06-03 12:26:00       2.08     12359.0          Cyprus
# ...

# %%
table['Country'].nunique()
# Out:
# 38

# %%
table['total_cost'] = table['Quantity']*table['UnitPrice']

# %%
first_grouping = table.groupby(['Country'])['total_cost'].sum()

# %%
first_grouping
# Out:
# Country
# Australia                137077.270
# Austria                   10154.320
# Bahrain                     548.400
# Belgium                   40910.960
# Brazil                     1143.600
# Canada                     3666.380
# Channel Islands           20086.290
# Cyprus                    12946.290
# Czech Republic              707.720
# Denmark                   18768.140
# EIRE                     263276.820
# European Community         1291.750
# Finland                   22326.740
# France                   197403.900
# Germany                  221698.210
# Greece                     4710.520
# Hong Kong                 10117.040
# Iceland                    4310.000
# Israel                     7907.820
# Italy                     16890.510
# Japan                     35340.620
# Lebanon                    1693.880
# Lithuania                  1661.060
# Malta                      2505.470
# Netherlands              284661.540
# Norway                    35163.460
# ...

# %%
first_grouping = first_grouping.to_frame()

# %%
first_grouping
# Out:
#                        total_cost
# Country
# Australia              137077.270
# Austria                 10154.320
# Bahrain                   548.400
# Belgium                 40910.960
# Brazil                   1143.600
# Canada                   3666.380
# Channel Islands         20086.290
# Cyprus                  12946.290
# Czech Republic            707.720
# Denmark                 18768.140
# EIRE                   263276.820
# European Community       1291.750
# Finland                 22326.740
# France                 197403.900
# Germany                221698.210
# Greece                   4710.520
# Hong Kong               10117.040
# Iceland                  4310.000
# Israel                   7907.820
# Italy                   16890.510
# Japan                   35340.620
# Lebanon                  1693.880
# Lithuania                1661.060
# Malta                    2505.470
# Netherlands            284661.540
# Norway                  35163.460
# ...

# %%
chart_table = first_grouping.sort_values(by=['total_cost'], ascending=False).head(10)

# %%
chart_table
# Out:
#                  total_cost
# Country
# United Kingdom  8187806.364
# Netherlands      284661.540
# EIRE             263276.820
# Germany          221698.210
# France           197403.900
# Australia        137077.270
# Switzerland       56385.350
# Spain             54774.580
# Belgium           40910.960
# Sweden            36595.910

# %%
chart_table = chart_table.drop(index='United Kingdom')

# %%
x_axis = chart_table.index

# %%
y_axis = chart_table['total_cost']

# %%
# %matplotlib notebook
# Dependencies
import matplotlib.pyplot as plt

# %%
plt.bar(x_axis, y_axis, color='r', alpha=0.5,align='center')
# Give our chart some labels and a tile
plt.title("Total cost per Country")
plt.xlabel("country")
plt.ylabel("Cost in dollars")
plt.xticks(x_axis,rotation=90)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="940.4444444444445">

# %%
import pandas as pd
# %matplotlib notebook
# Dependencies
import matplotlib.pyplot as plt
import numpy as np

# %%
file_to_load = "C:/Users/Admin/Databases/Cars.csv"

# %%
cars_table = pd.read_csv(file_to_load,)
cars_table
# Out:
#       Id      Brand     Model  Year   Price Initial_day  Final_Day Quote_price
# 0      1  Chevrolet  Corvette  2018  24,038  10/12/2017   1/1/2018     $2,781
# 1      2  Chevrolet  Corvette  2017  17,686  10/19/2017  1/10/2018     $2,917
# 2      3  Chevrolet  Corvette  2016  17,503  10/20/2017   1/4/2018     $3,826
# 3      4  Chevrolet  Corvette  2017  33,249  10/21/2017   1/3/2018     $3,816
# 4      5  Chevrolet  Corvette  2017  22,611  10/22/2017   1/8/2018     $3,846
# ..   ...        ...       ...   ...     ...         ...        ...         ...
# 920  921  Chevrolet  Corvette  2018  22,932  12/30/2018  3/13/2019     $2,509
# 921  922     Nissan    Altima  2017  16,657  12/30/2018  1/31/2019     $2,394
# 922  923       Ford     F-150  2017   3,443  12/30/2018  2/27/2019     $2,872
# 923  924  Chevrolet  Corvette  2017   8,789  12/31/2018  3/14/2019     $2,830
# 924  925       Ford     F-150  2016  37,384  12/31/2018  2/28/2019     $3,027
#
# [925 rows x 8 columns]

# %%
cars_table['Quote_price'] = cars_table['Quote_price'].str.strip('$')

# %%
cars_table['Quote_price']
# Out:
# 0      2,781
# 1      2,917
# 2      3,826
# 3      3,816
# 4      3,846
#         ...
# 920    2,509
# 921    2,394
# 922    2,872
# 923    2,830
# 924    3,027
# Name: Quote_price, Length: 925, dtype: object

# %%
cars_table.dtypes
# Out:
# Id              int64
# Brand          object
# Model          object
# Year            int64
# Price          object
# Initial_day    object
# Final_Day      object
# Quote_price    object
# dtype: object

# %%
import datetime

# %%
cars_table['Initial_day'] = pd.to_datetime(cars_table['Initial_day'])

# %%
cars_table['Final_Day'] = pd.to_datetime(cars_table['Final_Day'])

# %%
cars_table['Quote_price'] = cars_table['Quote_price'].str.replace(',','')

# %%
cars_table['Price'] = cars_table['Price'].str.replace(',','')

# %%
cars_table
# Out:
#       Id      Brand     Model  Year  Price Initial_day  Final_Day Quote_price
# 0      1  Chevrolet  Corvette  2018  24038  2017-10-12 2018-01-01       2781
# 1      2  Chevrolet  Corvette  2017  17686  2017-10-19 2018-01-10       2917
# 2      3  Chevrolet  Corvette  2016  17503  2017-10-20 2018-01-04       3826
# 3      4  Chevrolet  Corvette  2017  33249  2017-10-21 2018-01-03       3816
# 4      5  Chevrolet  Corvette  2017  22611  2017-10-22 2018-01-08       3846
# ..   ...        ...       ...   ...    ...         ...        ...         ...
# 920  921  Chevrolet  Corvette  2018  22932  2018-12-30 2019-03-13       2509
# 921  922     Nissan    Altima  2017  16657  2018-12-30 2019-01-31       2394
# 922  923       Ford     F-150  2017   3443  2018-12-30 2019-02-27       2872
# 923  924  Chevrolet  Corvette  2017   8789  2018-12-31 2019-03-14       2830
# 924  925       Ford     F-150  2016  37384  2018-12-31 2019-02-28       3027
#
# [925 rows x 8 columns]

# %%
cars_table['Quote_price'] = pd.to_numeric(cars_table['Quote_price'], downcast='integer')

# %%
cars_table['Price'] = pd.to_numeric(cars_table['Price'], downcast='integer')

# %%
cars_table.dtypes
# Out:
# Id                      int64
# Brand                  object
# Model                  object
# Year                    int64
# Price                   int32
# Initial_day    datetime64[ns]
# Final_Day      datetime64[ns]
# Quote_price             int16
# dtype: object

# %%
cars_table['Year'].value_counts()
# Out:
# 2016    319
# 2018    311
# 2017    295
# Name: Year, dtype: int64

# %%
Filter_data = cars_table.loc[(cars_table['Year'] == 2018) & (cars_table['Price'] >= 15000) & (cars_table['Price'] <= 20000)].sort_values(by=['Price'])

# %%
first_grouping = Filter_data.groupby(['Year'])['Price'].mean()

# %%
first_grouping
# Out:
# Year
# 2018    17582.674419
# Name: Price, dtype: float64

# %%
cars_table_grouping = cars_table.groupby(['Year'])['Price'].mean()

# %%
cars_table_grouping = cars_table_grouping.to_frame()

# %%
cars_table_grouping
# Out:
#              Price
# Year
# 2016  21582.147335
# 2017  21017.064407
# 2018  22427.784566

# %%
x_axis = cars_table_grouping.index
y_axis = cars_table_grouping['Price']

# %%
# %matplotlib notebook
# Dependencies
import matplotlib.pyplot as plt

# %%
plt.bar(x_axis, y_axis, color='b', alpha=0.5,align='center')
# Give our chart some labels and a tile
plt.title("Total cost per Country")
plt.xlabel("country")
plt.ylabel("Cost in dollars")
plt.xticks(x_axis)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
cars_table_grouping.dtypes
# Out:
# Price    float64
# dtype: object

# %%
cars_table.dtypes
# Out:
# Id                      int64
# Brand                  object
# Model                  object
# Year                    int64
# Price                   int32
# Initial_day    datetime64[ns]
# Final_Day      datetime64[ns]
# Quote_price             int16
# dtype: object

# %%
cars_table['time_difference'] = cars_table['Final_Day'] - cars_table['Initial_day']

# %%
cars_table['time_difference']
# Out:
# 0     81 days
# 1     83 days
# 2     76 days
# 3     74 days
# 4     78 days
#         ...
# 920   73 days
# 921   32 days
# 922   59 days
# 923   73 days
# 924   59 days
# Name: time_difference, Length: 925, dtype: timedelta64[ns]

# %%
cars_table['Brand'].nunique()
# Out:
# 3

# %%
cars_table['Brand'].value_counts()
# Out:
# Chevrolet    440
# Ford         285
# Nissan       200
# Name: Brand, dtype: int64

# %%
Brand_table = cars_table['Brand'].value_counts()
Brand_table
# Out:
# Chevrolet    440
# Ford         285
# Nissan       200
# Name: Brand, dtype: int64

# %%
Brand_table = Brand_table.to_frame()
Brand_table
# Out:
#            Brand
# Chevrolet    440
# Ford         285
# Nissan       200

# %%
Brand_table.dtypes
# Out:
# Brand    int64
# dtype: object

# %%
x_axis = Brand_table.index

# %%
y_axis = Brand_table['Brand']
xticks = Brand_table.index

# %%
# %matplotlib notebook
# Dependencies
import matplotlib.pyplot as plt

# %%
plt.bar(x_axis, y_axis, color='r', alpha=0.5,align='center')
# Give our chart some labels and a tile
plt.title("Total cost per Country")
plt.xlabel("country")
plt.ylabel("Cost in dollars")
plt.xticks(x_axis)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
