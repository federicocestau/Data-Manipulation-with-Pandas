# %%
import pandas as pd

# %%
file_to_load = "C:/Users/Admin/AWS/pivot sample.csv"

# %%
pivot_table = pd.read_csv(file_to_load)

# %%
pivot_table
# Out:
#            Entity Code  Year  DALYs (Disability-Adjusted Life Years)
# 0     Afghanistan  AFG  1990                                0.187690
# 1     Afghanistan  AFG  1991                                0.193772
# 2     Afghanistan  AFG  1992                                0.204869
# 3     Afghanistan  AFG  1993                                0.206346
# 4     Afghanistan  AFG  1994                                0.200465
# ...           ...  ...   ...                                     ...
# 6835     Zimbabwe  ZWE  2015                                0.583358
# 6836     Zimbabwe  ZWE  2016                                0.604536
# 6837     Zimbabwe  ZWE  2017                                0.626932
# 6838     Zimbabwe  ZWE  2018                                0.663348
# 6839     Zimbabwe  ZWE  2019                                0.694364
#
# [6840 rows x 4 columns]

# %%
import numpy as np

# %%
table = pd.pivot_table(pivot_table, values='DALYs (Disability-Adjusted Life Years)', index=['Year'],
                    columns=['Entity'], aggfunc=np.sum)

# %%
table
# Out:
# Entity  Afghanistan  African Region (WHO)   Albania   Algeria  American Samoa  \
# Year
# 1990       0.187690              0.210531  0.812691  0.381216        0.810317
# 1991       0.193772              0.214560  0.823587  0.404491        0.814240
# 1992       0.204869              0.218587  0.845726  0.427132        0.816131
# 1993       0.206346              0.220233  0.883713  0.451330        0.816520
# 1994       0.200465              0.208874  0.941578  0.473857        0.820458
# 1995       0.203585              0.223780  0.965325  0.499225        0.825987
# 1996       0.207814              0.224105  0.978901  0.535874        0.830911
# 1997       0.206594              0.226663  0.878888  0.550978        0.847001
# 1998       0.197661              0.228353  1.046866  0.584065        0.808629
# 1999       0.208584              0.229228  1.022892  0.625265        0.800301
# 2000       0.211379              0.231858  1.043935  0.648244        0.788171
# ...
