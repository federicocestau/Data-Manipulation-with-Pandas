# %%
import re

# %% [markdown]
# # Function	Description
#
# #findall	Returns a list containing all matches
#
# #search	Returns a Match object if there is a match anywhere in the string
#
# #split	Returns a list where the string has been split at each match
#
# #sub	Replaces one or many matches with a string

# %% [markdown]
# # Metacharacters
# Metacharacters are characters with a special meaning:

# %%
#A set of characters	"[a-m]"

# %%
txt = "The rain in Spain"

#Find all lower case characters alphabetically between "a" and "m":

x = re.findall("[a-mS]", txt)
x
# Out:
# ['h', 'e', 'a', 'i', 'i', 'S', 'a', 'i']

# %%
txt = "That will be 59 dollars 45 6 78 8 4"

#Find all digit characters:

x = re.findall("\d", txt)
x
# Out:
# ['5', '9', '4', '5', '6', '7', '8', '8', '4']

# %%
txt = "hello world"

#Search for a sequence that starts with "he", followed by two (any) characters, and an "o":

x = re.findall("he..o", txt)
x
# Out:
# ['hello']

# %%
txt = "hello world"

#Check if the string starts with 'hello':

x = re.findall("^hello", txt)
if x:
  print("Yes, the string starts with 'hello'")
else:
  print("No match")
# Out:
# Yes, the string starts with 'hello'

# %%
txt = "hello world helloy"

#Check if the string ends with 'world':
#does not end with world.

x = re.findall("world$", txt)
if x:
  print("Yes, the string ends with 'world'")
else:
  print("No match")
# Out:
# No match

# %%
txt = "The rain in Spain falls mainly in the plain!"

#Check if the string contains "ai" followed by 0 or more "x" characters:

x = re.findall("ai", txt)

print(x)

if x:
  print("Yes, there is at least one match!")
else:
  print("No match")
# Out:
# ['ai', 'ai', 'ai', 'ai']
# Yes, there is at least one match!

# %%
txt = "The rain in Spainvefpo falls mainly in the plain!"

#Check if the string contains "ai" followed by 1 or more "x" characters:

x = re.findall("ai\w+", txt)

print(x)

if x:
  print("Yes, there is at least one match!")
else:
  print("No match")
# Out:
# ['ain', 'ainvefpo', 'ainly', 'ain']
# Yes, there is at least one match!

# %%
txt = "The rain in Spain falls mainly in the plain!"

#Check if the string contains "a" followed by exactly two "l" characters:

x = re.findall("al{2}", txt)

print(x)

if x:
  print("Yes, there is at least one match!")
else:
  print("No match")
# Out:
# ['all']
# Yes, there is at least one match!

# %%
txt = "The rain in Spain falls mainly in the plain!"

#Check if the string contains "a" followed by exactly two "l" characters:

x = re.findall("al{2}|ai", txt)

print(x)

if x:
  print("Yes, there is at least one match!")
else:
  print("No match")
# Out:
# ['ai', 'ai', 'all', 'ai', 'ai']
# Yes, there is at least one match!

# %%
#Special Sequences
#A special sequence is a \ followed by one of the characters in the list below, and has a special meaning:

# %%
txt = "The rain in Spain"

#Check if the string starts with "The":

x = re.findall("\AThe", txt)

print(x)

if x:
  print("Yes, there is a match!")
else:
  print("No match")
# Out:
# ['The']
# Yes, there is a match!

# %%
txt = "The rain in Spain"

#Check if the string starts with "The":

x = re.findall("^The", txt)

print(x)

if x:
  print("Yes, there is a match!")
else:
  print("No match")
# Out:
# ['The']
# Yes, there is a match!

# %%
txt = "The rain in Spain"

#Check if "rai" is present at the beginning of a WORD:

x = re.findall(r"\brai", txt)

print(x)

if x:
  print("Yes, there is at least one match!")
else:
  print("No match")
# Out:
# ['rai']
# Yes, there is at least one match!

# %%
txt = "The rain in Spain"

#Check if "ain" is present at the end of a WORD:

x = re.findall(r"pain\b", txt)

print(x)

if x:
  print("Yes, there is at least one match!")
else:
  print("No match")
# Out:
# ['pain']
# Yes, there is at least one match!

# %%
txt = "The rain 45 in r34 Spain 34 56 897"

#Check if the string contains any digits (numbers from 0-9):

x = re.findall("\d", txt)

print(x)

if x:
  print("Yes, there is at least one match!")
else:
  print("No match")
# Out:
# ['4', '5', '3', '4', '3', '4', '5', '6', '8', '9', '7']
# Yes, there is at least one match!

# %%
#\B is the opposite of /b NOT at the beginning.

# %%
txt = "The rain 45 in r34 Spain 34 56 897"

#does not start with ain.

x = re.findall("\Bain", txt)

print(x)

if x:
  print("Yes, there is at least one match!")
else:
  print("No match")
# Out:
# ['ain', 'ain']
# Yes, there is at least one match!

# %%
txt = "The rain 45 in r34 Spain 34 56 897"

#does not start with ain.

x = re.findall("Spa\B", txt)

print(x)

if x:
  print("Yes, there is at least one match!")
else:
  print("No match")
# Out:
# ['Spa']
# Yes, there is at least one match!

# %%
txt = "The rain in Spain"

#Return a match at every no-digit character:

x = re.findall("\D", txt)

print(x)

if x:
  print("Yes, there is at least one match!")
else:
  print("No match")
# Out:
# ['T', 'h', 'e', ' ', 'r', 'a', 'i', 'n', ' ', 'i', 'n', ' ', 'S', 'p', 'a', 'i', 'n']
# Yes, there is at least one match!

# %%
txt = "The rain in Spain"

#Return a match at every white-space character:

x = re.findall("\s", txt)

print(x)

if x:
  print("Yes, there is at least one match!")
else:
  print("No match")
# Out:
# [' ', ' ', ' ']
# Yes, there is at least one match!

# %%
txt = "The rain in Spain"

#Return a match at every NON white-space character:

x = re.findall("\S", txt)

print(x)

if x:
  print("Yes, there is at least one match!")
else:
  print("No match")
# Out:
# ['T', 'h', 'e', 'r', 'a', 'i', 'n', 'i', 'n', 'S', 'p', 'a', 'i', 'n']
# Yes, there is at least one match!

# %%
txt = "The rain in Spain_"

#Return a match at every word character (characters from a to Z, digits from 0-9, and the underscore _ character):
#does not include spaces.
x = re.findall("\w", txt)

print(x)

if x:
  print("Yes, there is at least one match!")
else:
  print("No match")
# Out:
# ['T', 'h', 'e', 'r', 'a', 'i', 'n', 'i', 'n', 'S', 'p', 'a', 'i', 'n', '_']
# Yes, there is at least one match!

# %%
txt = "The rain in Spain (1)*&^5$#@!"

#Return a match at every NON word character (characters NOT between a and Z. Like "!", "?" white-space etc.):

x = re.findall("\W", txt)

print(x)

if x:
  print("Yes, there is at least one match!")
else:
  print("No match")
# Out:
# [' ', ' ', ' ', ' ', '(', ')', '*', '&', '^', '$', '#', '@', '!']
# Yes, there is at least one match!

# %%
txt = "The rain in Spain"

#Check if the string ends with "Spain":

x = re.findall("Spain\Z", txt)

print(x)

if x:
  print("Yes, there is a match!")
else:
  print("No match")
# Out:
# ['Spain']
# Yes, there is a match!

# %%
txt = "The rain in Spain"

#Check if the string ends with "Spa":

x = re.findall("Spa\Z", txt)

print(x)

if x:
  print("Yes, there is a match!")
else:
  print("No match")
# Out:
# []
# No match

# %%
txt = "The rain in Spain"

#Check if the string ends with "Spa":

x = re.findall("Spain$", txt)

print(x)

if x:
  print("Yes, there is a match!")
else:
  print("No match")
# Out:
# ['Spain']
# Yes, there is a match!

# %% [markdown]
# RegEx Sets

# %%
txt = "The rain in Spain"

#Check if the string has any a, r, or n characters:
#in the order it finds the characters

x = re.findall("[arn]", txt)

print(x)

if x:
  print("Yes, there is at least one match!")
else:
  print("No match")
# Out:
# ['r', 'a', 'n', 'n', 'a', 'n']
# Yes, there is at least one match!

# %%
txt = "The rain in Spain"

#Check if the string has any characters between a and n:

x = re.findall("[a-nTS]", txt)

print(x)

if x:
  print("Yes, there is at least one match!")
else:
  print("No match")
# Out:
# ['T', 'h', 'e', 'a', 'i', 'n', 'i', 'n', 'S', 'a', 'i', 'n']
# Yes, there is at least one match!

# %%
txt = "The rain in Spain"

#Check if the string has other characters than a, r, or n:

x = re.findall("[^ast]", txt)

print(x)

if x:
  print("Yes, there is at least one match!")
else:
  print("No match")
# Out:
# ['T', 'h', 'e', ' ', 'r', 'i', 'n', ' ', 'i', 'n', ' ', 'S', 'p', 'i', 'n']
# Yes, there is at least one match!

# %%
txt = "The 0 rain 1 1 3 3 3 in Spain 2 2"

#Check if the string has any 0, 1, 2, or 3 digits:

x = re.findall("[0123]", txt)

print(x)

if x:
  print("Yes, there is at least one match!")
else:
  print("No match")
# Out:
# ['0', '1', '1', '3', '3', '3', '2', '2']
# Yes, there is at least one match!

# %%
txt = "8 times before 11:45 AM 6 7 8 9"

#Check if the string has any digits:

x = re.findall("[0-9]", txt)

print(x)

if x:
  print("Yes, there is at least one match!")
else:
  print("No match")
# Out:
# ['8', '1', '1', '4', '5', '6', '7', '8', '9']
# Yes, there is at least one match!

# %%
txt = "8 times before 11:48 AM"

#Check if the string has any two-digit numbers, from 00 to 59:
#first number between 0-5 second between 0-9.
#does not match 48 bc it is less than 9 the second digit.
x = re.findall("[0-5][0-7]", txt)

print(x)

if x:
  print("Yes, there is at least one match!")
else:
  print("No match")
# Out:
# ['11']
# Yes, there is at least one match!

# %%
txt = "8 times before 11:48 AM"

#Check if the string has any two-digit numbers, from 00 to 59:
#first number between 0-5 second between 0-9.
#does not match 48 bc it is less than 9 the second digit.
x = re.findall("[0-5][0-9]", txt)

print(x)

if x:
  print("Yes, there is at least one match!")
else:
  print("No match")
# Out:
# ['11', '48']
# Yes, there is at least one match!

# %%
txt = "8 times before 11:45 AM"

#Check if the string has any characters from a to z lower case, and A to Z upper case:
#findAll gives you a list with values of the string.
x = re.findall("[a-zA-Z]", txt)

print(x)

if x:
  print("Yes, there is at least one match!")
else:
  print("No match")
# Out:
# ['t', 'i', 'm', 'e', 's', 'b', 'e', 'f', 'o', 'r', 'e', 'A', 'M']
# Yes, there is at least one match!

# %%
txt = "8 times before 11:45 AM"

#Check if the string has any characters from a to z lower case, and A to Z upper case:
#findAll gives you a list with values of the string.
x = re.findall("\w+", txt)

print(x)

if x:
  print("Yes, there is at least one match!")
else:
  print("No match")
# Out:
# ['8', 'times', 'before', '11', '45', 'AM']
# Yes, there is at least one match!

# %%
txt = "8 times before 11:45 AM"

#Check if the string has any characters from a to z lower case, and A to Z upper case:
#findAll gives you a list with values of the string.
x = re.findall(" ", txt)

print(x)

if x:
  print("Yes, there is at least one match!")
else:
  print("No match")
# Out:
# [' ', ' ', ' ', ' ']
# Yes, there is at least one match!

# %%
txt = "8 times before 11:45 AM"


#Check if the string has any characters from a to z lower case, and A to Z upper case:
#findAll gives you a list with values of the string.
#Same as \s+
x = re.findall("\s", txt)

print(x)

if x:
  print("Yes, there is at least one match!")
else:
  print("No match")
# Out:
# [' ', ' ', ' ', ' ']
# Yes, there is at least one match!

# %%
txt = "8 times before 11:45 AM +"

#Check if the string has any + characters:

x = re.findall("[+]", txt)

print(x)

if x:
  print("Yes, there is at least one match!")
else:
  print("No match")
# Out:
# ['+']
# Yes, there is at least one match!

# %%
#A Match Object is an object containing information about the search and the result.

# %%
#it takes the first match
txt = "The rain in Spain"
x = re.search("ai", txt)
x
# Out:
# <re.Match object; span=(5, 7), match='ai'>

# %%
#span() returns a tuple containing the start-, and end positions of the match.
txt = "The rain in Spain"
x = re.search(r"\bS\w+", txt)
x
# Out:
# <re.Match object; span=(12, 17), match='Spain'>

# %%
txt = "The rain in Spain"
x = re.search(r"\bS\w+", txt)
x.string
# Out:
# 'The rain in Spain'

# %%
txt = "The rain Solo in Spain"
x = re.search(r"\bS\w+", txt)
x
# Out:
# <re.Match object; span=(9, 13), match='Solo'>

# %% [markdown]
# The re module offers a set of functions that allows us to search a string for a match:

# %% [markdown]
# #^a...s$

# %% [markdown]
# The pattern is: any five letter string starting with a and ending with s.

# %% [markdown]
# abs	No match
# alias	Match
# abyss	Match
# Alias	No match
# An abacus	No match

# %%
import re

pattern = '^a...s$'
test_string = 'abyss'
result = re.match(pattern, test_string)

if result:
  print("Search successful.")
else:
  print("Search unsuccessful.")
# Out:
# Search successful.

# %%
result
# Out:
# <re.Match object; span=(0, 5), match='abyss'>

# %% [markdown]
# MetaCharacters

# %% [markdown]
# [] . ^ $ * + ? {} () \ |

# %%
#Square brackets specifies a set of characters you wish to match.

# %%
txt = "The rain in Spain"
x = re.search("ai", txt)
x
# Out:
# <re.Match object; span=(5, 7), match='ai'>

# %%
text = '''Ha! let me see her : out, alas! he's cold:
    Her blood is settled, and her joints are stiff
    Life and these lips have long been separated:
    Death lies on her like an untimely frost
    Upon the sweetest flower of all the field.'''

# %%
#Her is not taken.
re.findall('her', text)
# Out:
# ['her', 'her', 'her']

# %%
#The first match with the index location. Does not include the last number 18.
re.search('her', text)
# Out:
# <re.Match object; span=(15, 18), match='her'>

# %%
re.split(':', text)
# Out:
# ['Ha! let me see her ',
#  " out, alas! he's cold",
#  '\n    Her blood is settled, and her joints are stiff\n    Life and these lips have long been separated',
#  '\n    Death lies on her like an untimely frost\n    Upon the sweetest flower of all the field.']

# %% [markdown]
# replace()

# %%
s = 'one two one two one'

# %%
s.replace(' ', '-')
# Out:
# 'one-two-one-two-one'

# %%
s.replace('one', 'XXX')
# Out:
# 'XXX two XXX two XXX'

# %%
s.replace('one', 'XXX').replace('two', 'YYY')
# Out:
# 'XXX YYY XXX YYY XXX'

# %%
s_lines = 'one\ntwo\nthree'

# %%
#behind the scenes \n is a new line.
s_lines
# Out:
# 'one\ntwo\nthree'

# %% [markdown]
# #splitlines()

# %%
s_lines_multi1 = 'one\ntwo\r\nthree'
s_lines_multi1
# Out:
# 'one\ntwo\r\nthree'

# %%
s_lines_multi.replace('\r\n', '-').replace('\n', '-')
# Out:
# 'one-two-three'

# %%
s_lines_multi2 = s_lines_multi1.splitlines()
s_lines_multi2
# Out:
# ['one', 'two', 'three']

# %% [markdown]
# join() which combines lists with strings.

# %%
#list with strings
list1 = ['1','2','3','4']

# %%
s = "-"

# %%
J = s.join(list1)
J
# Out:
# '1-2-3-4'

# %%
J1 = "-".join(list1)
J1
# Out:
# '1-2-3-4'

# %% [markdown]
# Use the translate() method to replace multiple different characters.

# %%
s2 = 'one two one two one'

# %%
s2.translate(str.maketrans({'o': 'O', 't': 'T'}))
# Out:
# 'One TwO One TwO One'

# %%
s2.translate(str.maketrans({'o': 'XXX', 't': None}))
# Out:
# 'XXXne wXXX XXXne wXXX XXXne'

# %% [markdown]
# str.maketrans() can also take three strings as arguments instead of a dictionary.

# %%
s3 = 'one two one two one'

# %%
#reaplace in that order and delete the last argument in the string.
s3.translate(str.maketrans('owt', 'XYH', 'n'))
# Out:
# 'Xe HYX Xe HYX Xe'

# %%
s10 = 'aaa@xxx.com bbb@yyy.com ccc@zzz.com fnwio@www.com'

# %%
#Any character happening to the left of the @
S12 = re.sub('[a-z]*@', 'ABC@', s10)
S12
# Out:
# 'ABC@xxx.com ABC@yyy.com ABC@zzz.com ABC@www.com'

# %% [markdown]
# #As with replace(), you can specify the maximum count of replacements in the fourth argument count.

# %%
#only two times change. The others the same
S13 = re.sub('[a-z]*@', 'ABC@', s10, 2)
S13
# Out:
# 'ABC@xxx.com ABC@yyy.com ccc@zzz.com fnwio@www.com'

# %%
#subsitutes the inside bracket characters with 1.
S14 = re.sub('[ab]', '1', s10)
S14
# Out:
# '111@xxx.com 111@yyy.com ccc@zzz.com fnwio@www.com'

# %% [markdown]
# If patterns are delimited by |, it matches any pattern.

# %%
S15 = re.sub('aaa|bbb|ccc', 'ABC', s10)
S15
# Out:
# 'ABC@xxx.com ABC@yyy.com ABC@zzz.com fnwio@www.com'

# %%
S16 = re.sub('aaa|bbb', 'ABC', s10)
S16
# Out:
# 'ABC@xxx.com ABC@yyy.com ccc@zzz.com fnwio@www.com'

# %%
#\\1 corresponds to the part that matches 
S17 = re.sub('([a-z]*)@', '\\1-123@', s10)
S17
# Out:
# 'aaa-123@xxx.com bbb-123@yyy.com ccc-123@zzz.com fnwio-123@www.com'

# %% [markdown]
# re.subn() returns a tuple of the replaced string and the number of parts replaced.

# %%
t = re.subn('[a-z]*@', 'ABC@', s10)
t
# Out:
# ('ABC@xxx.com ABC@yyy.com ABC@zzz.com ABC@www.com', 4)

# %%
print(type(t))
# <class 'tuple'>

print(t[0])
# ABC@xxx.com ABC@yyy.com ABC@zzz.com

print(t[1])
# Out:
# <class 'tuple'>
# ABC@xxx.com ABC@yyy.com ABC@zzz.com ABC@www.com
# 4

# %%
s = 'abcdefghij'

# %%
#0,1,2,3
#the first four numbers.
s[:4]
# Out:
# 'abcd'

# %%
#starting from index 7 until the end.
s[7:]
# Out:
# 'hij'

# %%
s[:4] + 'XXX' + s[7:]
# Out:
# 'abcdXXXhij'

# %%
s[:4] + '-' + s[7:]
# Out:
# 'abcd-hij'

# %%
#from index 4 until the end.
s[4:]
# Out:
# 'efghij'

# %%
s[:4] + '+++++' + s[4:]
# Out:
# 'abcd+++++efghij'

# %%
text = "Python for beginner is a very cool website"
pattern = re.sub("cool", "good", text)
pattern
# Out:
# 'Python for beginner is a very good website'

# %%
# An example string.
v = "running eating reading"

# Replace words starting with "r" and ending in "ing"
# ... with a new string.
v2 = re.sub("r.*?ing", "ring", v)
v2
# Out:
# 'ring eating ring'

# %% [markdown]
# Basic patterns

# %%
#a, X, 9
#ordinary characters just match themselves exactly.

# %% [markdown]
# meta-characters with special meanings (see below)

# %% [markdown]
# w
# matches a “word” character: a letter or digit or underbar [a-zA-Z0-9_].

# %% [markdown]
# ^
# match the start of the string
#
# $
# match the of the string end
#
# *
# matches 0 or more repetitions
#
# ?
# matches 0 or 1 characters of whatever precedes it

# %%
str = 'purple alice-b@google.com monkey dishwasher'

# %%
match = re.search('\w+@\w+', str)
match
# Out:
# <re.Match object; span=(13, 21), match='b@google'>

# %%
match1 = re.search(r'[\w.-]+@[\w.-]+', str)
match1
# Out:
# <re.Match object; span=(7, 25), match='alice-b@google.com'>

# %%
match2 = re.search(r'([\w.-]+)@([\w.-]+)', str)
match2
# Out:
# <re.Match object; span=(7, 25), match='alice-b@google.com'>

# %%
match2.group(1)
# Out:
# 'alice-b'

# %%
match2.group(2)
# Out:
# 'google.com'

# %%
str = 'an example word:cat!!'
match = re.search('word:\w+', str)
match
# Out:
# <re.Match object; span=(11, 19), match='word:cat'>

# %%
match = re.search('iii', 'piiig') # found, match.group() == "iii"
match
# Out:
# <re.Match object; span=(1, 4), match='iii'>

# %%
#no match
match = re.search('igs', 'piiig') 
match

# %%
### . = any char but \n
match3 = re.search(r'..g', 'piiig') # found, match.group() == "iig"
match3
# Out:
# <re.Match object; span=(2, 5), match='iig'>

# %%
## \d = digit char, \w = word char
match4 = re.search(r'\d\d\d', 'p123g') # found, match.group() == "123"
match5 = re.search(r'\w\w\w', '@@abcd!!') # found, match.group() == "abc"

# %%
match4
# Out:
# <re.Match object; span=(1, 4), match='123'>

# %%
match5
# Out:
# <re.Match object; span=(2, 5), match='abc'>

# %%
match6 = re.search(r'\d+', 'p123g') # found, match.group() == "123"
match6
# Out:
# <re.Match object; span=(1, 4), match='123'>

# %%
match7 = re.search(r'\w+', 'p123g') # found, match.group() == "123"
match7
# Out:
# <re.Match object; span=(0, 5), match='p123g'>

# %%
match8 = re.search(r'\w+', '@@abcd!!') # found, match.group() == "abc"
match8
# Out:
# <re.Match object; span=(2, 6), match='abcd'>

# %% [markdown]
# Repetition Examples
#   ## i+ = one or more i's, as many as possible.
#   match = re.search(r'pi+', 'piiig') # found, match.group() == "piii"
#
#   ## Finds the first/leftmost solution, and within it drives the +
#   ## as far as possible (aka 'leftmost and largest').
#   ## In this example, note that it does not get to the second set of i's.
#   match = re.search(r'i+', 'piigiiii') # found, match.group() == "ii"
#
#   ## \s* = zero or more whitespace chars
#   ## Here look for 3 digits, possibly separated by whitespace.
#   match = re.search(r'\d\s*\d\s*\d', 'xx1 2   3xx') # found, match.group() == "1 2   3"
#   match = re.search(r'\d\s*\d\s*\d', 'xx12  3xx') # found, match.group() == "12  3"
#   match = re.search(r'\d\s*\d\s*\d', 'xx123xx') # found, match.group() == "123"
#
#   ## ^ = matches the start of string, so this fails:
#   match = re.search(r'^b\w+', 'foobar') # not found, match == None
#   ## but without the ^ it succeeds:
#   match = re.search(r'b\w+', 'foobar') # found, match.group() == "bar"

# %%
#i+ = one or more i's, as many as possible.
match9 = re.search('pi+', 'piiig') # found, match.group() == "piii"
match9
# Out:
# <re.Match object; span=(0, 4), match='piii'>

# %%
match10 = re.search(r'i+', 'piigiiii') # found, match.group() == "ii"
match10
# Out:
# <re.Match object; span=(1, 3), match='ii'>

# %% [markdown]
# Here look for 3 digits, possibly separated by whitespace.

# %%
match11 = re.search(r'\d\s\d\s\d', 'xx1 2 3xx') 
# found, match.group() == "1 2 3" 
match12 = re.search(r'\d\s+\d\s\d', 'xx1  2 3xxx') # found, match.group() == "12 3" 
match13 = re.search(r'\d+', 'xx123xx') # found, match.group() == "123"

# %%
match11
# Out:
# <re.Match object; span=(2, 7), match='1 2 3'>

# %%
match12
# Out:
# <re.Match object; span=(2, 8), match='1  2 3'>

# %%
match13
# Out:
# <re.Match object; span=(2, 5), match='123'>

# %% [markdown]
# ^ = matches the start of string, so this fails:

# %%
match14 = re.search(r'^b\w+', 'foobar') # not found, match == None
match14

# %%
match15 = re.search(r'^f\w+', 'fo23obar')
match15
# Out:
# <re.Match object; span=(0, 8), match='fo23obar'>

# %%
import re

# %%
str1 = 'purple alice-b@google.com monkey dishwasher'

# %%
match16 = re.search(r'[\w+\s\w+-]+@\w+.\w+\s\w+\s\w+', str1)
match16
# Out:
# <re.Match object; span=(0, 43), match='purple alice-b@google.com monkey dishwasher'>

# %%
str2 = 'Cookies are the best!'

# %%
match17 = re.search(r'\w.+\s\w+\s\w+\s\w+!', str2)
match17
# Out:
# <re.Match object; span=(0, 21), match='Cookies are the best!'>

# %%
#. - A period. Matches any single character except the newline character.

# %%
match18 = re.search(r'C..k.e', 'Cookie')
match18
# Out:
# <re.Match object; span=(0, 6), match='Cookie'>

# %%
#^ - Matches the start of the string.

# %%
match19 = re.search(r'^E..', "Eat cake!")
match19
# Out:
# <re.Match object; span=(0, 3), match='Eat'>

# %%
## However, the code below will not give the same result. Try it for yourself:
match20 = re.search(r'^eat', "Let's eat cake!")
match20

# %%
match21 = re.search(r'^Let', "Let's eat cake!")
match21
# Out:
# <re.Match object; span=(0, 3), match='Let'>

# %%
#$ - Matches the end of string.

# %%
match22 = re.search(r'cake$', "Cake! Let's eat cake")
match22
# Out:
# <re.Match object; span=(16, 20), match='cake'>

# %%
#[abc] - Matches a or b or c.Matches the first appearence
match23 = re.search(r'[bca]', " Cke! c Let's eat beer cake")
match23
# Out:
# <re.Match object; span=(6, 7), match='c'>

# %% [markdown]
# [a-zA-Z0-9] - Matches any letter from (a to z) or (A to Z) or (0 to 9).

# %%
#first match
match24 = re.search(r'[a-z]', " Cke! c Let's eat beer cake")
match24
# Out:
# <re.Match object; span=(2, 3), match='k'>

# %%
match25 = re.search(r'[A-Z]', " ke! c Let's eat beer cake")
match25
# Out:
# <re.Match object; span=(7, 8), match='L'>

# %%
match26 = re.search(r'[0-9]', " ke! c Let's eat beer 2134 cake")
match26
# Out:
# <re.Match object; span=(22, 23), match='2'>

# %%
match27 = re.search(r'\d+', " ke! c Let's eat beer 1234 cake")
match27
# Out:
# <re.Match object; span=(22, 26), match='1234'>

# %%
match28 = re.search(r'[0-6]', 'Number: 5')
match28
# Out:
# <re.Match object; span=(8, 9), match='5'>

# %%
#always the first match
match29 = re.search(r'[0-6]', 'Num3ber: 5')
match29
# Out:
# <re.Match object; span=(3, 4), match='3'>

# %% [markdown]
# \w - Lowercase 'w'. Matches any single letter, digit, or underscore.
# \W - Uppercase 'W'. Matches any character not part of \w (lowercase w).

# %%
match30 = re.search(r'\w+', 'Cookie')
match30
# Out:
# <re.Match object; span=(0, 6), match='Cookie'>

# %%
match31 = re.search(r'C\W+\d\W+', 'C@-*/&6%%$#')
match31
# Out:
# <re.Match object; span=(0, 11), match='C@-*/&6%%$#'>

# %%
#\s - Lowercase 's'. Matches a single whitespace character like: space, newline, tab, return.

# %%
match32 = re.search(r'Eat\scake', 'Eat cake')
match32
# Out:
# <re.Match object; span=(0, 8), match='Eat cake'>

# %%
match33 = re.search(r'\w+\s\w+', 'Eat cake')
match33
# Out:
# <re.Match object; span=(0, 8), match='Eat cake'>

# %% [markdown]
# \d - Lowercase d. Matches decimal digit 0-9.

# %%
match34 = re.search(r'^\d+', '100 cookies')
match34
# Out:
# <re.Match object; span=(0, 3), match='100'>

# %%
#it won't work not at the beginning. 
match35 = re.search(r'^\d+', 'cookies 100')
match35

# %% [markdown]
# \t - Lowercase t. Matches tab.
# \n - Lowercase n. Matches newline.
# \r - Lowercase r. Matches return.
# \A - Uppercase a. Matches only at the start of the string. Works across multiple lines as well.
# \Z - Uppercase z. Matches only at the end of the string.

# %% [markdown]
# ^ and \A are effectively the same, and so are $ and \Z.

# %%
#\b - Lowercase b. Matches only the beginning or end of the word.
match36 = re.search(r'\b[A-E]ookie', 'Cookie')
match36
# Out:
# <re.Match object; span=(0, 6), match='Cookie'>

# %%
match37 = re.search(r'\bookie[A-E]', 'ookieC')
match37
# Out:
# <re.Match object; span=(0, 6), match='ookieC'>

# %%
match38 = re.search(r'Co+kie', 'Cooookie')
match38
# Out:
# <re.Match object; span=(0, 8), match='Cooookie'>

# %%
str4 = 'purple alice-b@google.com monkey dishwasher'

# %%
#all the matches that are inside the brackets and what repeated with the +. 
match39 = re.search(r'[\w.-]+@[\w.]+', str4)
match39
# Out:
# <re.Match object; span=(7, 25), match='alice-b@google.com'>

# %%
match40 = re.search(r'dishwasher?', str4)
match40
# Out:
# <re.Match object; span=(33, 43), match='dishwasher'>

# %%
match41 = re.search(r'dishwasher', str4)
match41
# Out:
# <re.Match object; span=(33, 43), match='dishwasher'>

# %%
match42 = re.search(r'monkey', str4)
match42
# Out:
# <re.Match object; span=(26, 32), match='monkey'>

# %%
match43 = re.search(r'dish?', str4)
match43
# Out:
# <re.Match object; span=(33, 37), match='dish'>

# %% [markdown]
# {x} - Repeat exactly x number of times.
# {x,} - Repeat at least x times or more.
# {x, y} - Repeat at least x times but no more than y times.

# %%
match44 = re.search(r'\d{9,10}', '0987654321')
match44
# Out:
# <re.Match object; span=(0, 10), match='0987654321'>

# %%
#Exactly that number.
match45 = re.search(r'\d{9}', '0987654321')
match45
# Out:
# <re.Match object; span=(0, 9), match='098765432'>

# %%
statement = 'Please contact us at: support@datacamp.com'

# %%
match46 = re.search(r'([\w]+)@([\w\.]+)', statement)
match46
# Out:
# <re.Match object; span=(22, 42), match='support@datacamp.com'>

# %%
match47 = re.search(r'([\w\s:]+)@([\w\.]+)', statement)
match47
# Out:
# <re.Match object; span=(0, 42), match='Please contact us at: support@datacamp.com'>

# %%
if statement:
  print("Email address:", match46.group()) # The whole matched text
  print("Username:", match46.group(1)) # The username (group 1)
  print("Host:", match46.group(2)) # The host (group 2)
# Out:
# Email address: support@datacamp.com
# Username: support
# Host: datacamp.com

# %% [markdown]
# Another way of doing the same is with the usage of <> brackets instead. This will let you create named groups. Named groups will make your code more readable. The syntax for creating named group is: (?P<name>...). Replace the name part with the name you want to give to your group. The ... represent the rest of the matching syntax.

# %%
match = re.search(r'(?P<email>(?P<username>[\w]+)@(?P<host>[\w\.]+))', statement)
if statement:
   print("Email address:", match.group('email'))
   print("Username:", match.group('username'))
   print("Host:", match.group('host'))
# Out:
# Email address: support@datacamp.com
# Username: support
# Host: datacamp.com

# %% [markdown]
# $	Dollar sign. Matches the end of the string.
# \Z	Uppercase Z. Matches only at the end of the string.

# %%
statement2 = 'Please contact us at'

# %%
match48 = re.search(r'at$', statement2)
match48
# Out:
# <re.Match object; span=(18, 20), match='at'>

# %%
#it is not at the end.
match48 = re.search(r'contact$', statement2)
match48

# %%
heading  = r'<h1>TITLE</h1>'

# %%
# * is the same as ^

# %%
match49 = re.match(r'<.*>', heading)
match49
# Out:
# <re.Match object; span=(0, 14), match='<h1>TITLE</h1>'>

# %%
#Adding ? after the qualifier makes it perform the match in a non-greedy or minimal fashion; That is, as few characters as possible will be matched.
#with that format.

# %%
match50 = re.match(r'<.*?>', heading)
match50
# Out:
# <re.Match object; span=(0, 4), match='<h1>'>

# %% [markdown]
# Regular expressions are handled as strings by Python. However, with compile(), you can computer a regular expression pattern into a regular expression object. When you need to use an expression several times in a single program, using compile() to save the resulting regular expression object for reuse is more efficient than saving it as a string.

# %%
pattern = re.compile(r"cookie")
sequence = "Cake and cookie"
pattern.search(sequence)
# Out:
# <re.Match object; span=(9, 15), match='cookie'>

# %%
pattern = "C"
sequence1 = "IceCream"
sequence2 = "Cake"

# No match since "C" is not at the start of "IceCream"
print("Sequence 1: ", re.match(pattern, sequence1))
print("Sequence 2: ", re.match(pattern,sequence2))
# Out:
# Sequence 1:  None
# Sequence 2:  <re.Match object; span=(0, 1), match='C'>

# %% [markdown]
# search() versus match()
#
# The match() function checks for a match only at the beginning of the string (by default), whereas the search() function checks for a match anywhere in the string.

# %% [markdown]
# findall(pattern, string, flags=0)
#
# Finds all the possible matches in the entire sequence and returns them as a list of strings. Each returned string represents one match.

# %% [markdown]
# Finds all the possible matches in the entire sequence and returns them as a list of strings. Each returned string represents one match.

# %%
import re

# %%
statement = "Please contact us at: support@datacamp.com, xyz@datacamp.com"

#'addresses' is a list that stores all the possible match
addresses = re.findall(r'[\w]+@[\w\.]+', statement)
for address in addresses:
    print(address)
# Out:
# support@datacamp.com
# xyz@datacamp.com

# %%
#Finds all the possible matches in the entire sequence and returns them as a list of strings. 
#Each returned string represents one match.
addresses
# Out:
# ['support@datacamp.com', 'xyz@datacamp.com']

# %% [markdown]
# finditer() might be an excellent choice when you want to have more information returned to you about your search. The returned regex match object holds not only the sequence that matched but also their positions in the original text.

# %%
statement = "Please contact us at: support@datacamp.com, xyz@datacamp.com"

#'addresses' is a list that stores all the possible match
addresses2 = re.finditer(r'[\w]+@[\w\.]+', statement)
for address in addresses2:
    print(address)
# Out:
# <re.Match object; span=(22, 42), match='support@datacamp.com'>
# <re.Match object; span=(44, 60), match='xyz@datacamp.com'>

# %%
addresses2

# %%
statement3 = "Please contact us at: support@datacamp.com, xyz@datacamp.com"

# %%
new_email_address = re.sub(r'([\w]+)@([\w\.]+)', r'federico@datacamp.com', statement3)
new_email_address
# Out:
# 'Please contact us at: federico@datacamp.com, federico@datacamp.com'

# %% [markdown]
# The subn() is similar to sub(). However, it returns a tuple containing the new string value and the number of replacements that were performed in the statement.

# %%
new_email_address2 = re.subn(r'([\w]+)@([\w\.]+)', r'federico@datacamp.com', statement3)
new_email_address2
# Out:
# ('Please contact us at: federico@datacamp.com, federico@datacamp.com', 2)

# %%
statement4 = "Please contact us at: xyz@datacamp.com, support@datacamp.com"
pattern = re.compile(r'[:,]')

address = pattern.split(statement4)
print(address)
# Out:
# ['Please contact us at', ' xyz@datacamp.com', ' support@datacamp.com']

# %% [markdown]
# This splits the strings wherever the pattern matches and returns a list.

# %%
pattern = re.compile('cookie')

# %%
match = pattern.search("I am not a cookie monster")
match
# Out:
# <re.Match object; span=(11, 17), match='cookie'>

# %%
print("Start index:", match.start())
print("End index:", match.end())
print("Tuple:", match.span())
# Out:
# Start index: 11
# End index: 17
# Tuple: (11, 17)

# %%
str13 = 'Hello (python) world'
str14 = re.search("\w+\s\(\w+\)\s\w+", str13)
str14
# Out:
# <re.Match object; span=(0, 20), match='Hello (python) world'>

# %%
import requests
the_idiot_url = 'https://www.gutenberg.org/files/2638/2638-0.txt'

# %%
def get_book(url):
    # Sends a http request to get the text from project Gutenberg
    raw = requests.get(url).text
    # Discards the metadata from the beginning of the book
    start = re.search(r"\*\*\* START OF THIS PROJECT GUTENBERG EBOOK .* \*\*\*",raw ).end()
    # Discards the text starting Part 2 of the book
    stop = re.search(r"II", raw).start()
    # Keeps the relevant text
    text = raw[start:stop]
    return text

# %%
raw = requests.get(the_idiot_url).text
raw
# Out:
# 'ï»¿The Project Gutenberg EBook of The Idiot, by Fyodor Dostoyevsky\r\n\r\nThis eBook is for the use of anyone anywhere at no cost and with\r\nalmost no restrictions whatsoever.  You may copy it, give it away or\r\nre-use it under the terms of the Project Gutenberg License included\r\nwith this eBook or online at www.gutenberg.org\r\n\r\n\r\nTitle: The Idiot\r\n\r\nAuthor: Fyodor Dostoyevsky\r\n\r\nTranslator: Eva Martin\r\n\r\nPosting Date: April 5, 2012 [EBook #2638]\r\nRelease Date: May, 2001\r\nLast Updated: May 13, 2017\r\n\r\nLanguage: English\r\n\r\nCharacter set encoding: UTF-8\r\n\r\n*** START OF THIS PROJECT GUTENBERG EBOOK THE IDIOT ***\r\n\r\n\r\n\r\n\r\nProduced by Martin Adamson, David Widger, with corrections by Andrew Sly\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\nTHE IDIOT\r\n\r\nBy Fyodor Dostoyevsky\r\n\r\n\r\nTranslated by Eva Martin\r\n\r\n\r\n\r\n\r\nPART I\r\n\r\nI.\r\n\r\nTowards the end of November, during a thaw, at nine oâ\x80\x99clock one morning,\r\na tra
# ...

# %%
start = re.search(r"\*\*\* START OF THIS PROJECT GUTENBERG EBOOK .* \*\*\*",raw ).end()
start
# Out:
# 610

# %%
stop = re.search(r"II", raw).start()
stop
# Out:
# 25283

# %%
def preprocess(sentence):
    return re.sub('[^A-Za-z0-9.]+',' ', sentence).lower()

# %%
book = get_book(the_idiot_url)
book
# Out:
# '\r\n\r\n\r\n\r\n\r\nProduced by Martin Adamson, David Widger, with corrections by Andrew Sly\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\nTHE IDIOT\r\n\r\nBy Fyodor Dostoyevsky\r\n\r\n\r\nTranslated by Eva Martin\r\n\r\n\r\n\r\n\r\nPART I\r\n\r\nI.\r\n\r\nTowards the end of November, during a thaw, at nine oâ\x80\x99clock one morning,\r\na train on the Warsaw and Petersburg railway was approaching the latter\r\ncity at full speed. The morning was so damp and misty that it was only\r\nwith great difficulty that the day succeeded in breaking; and it was\r\nimpossible to distinguish anything more than a few yards away from the\r\ncarriage windows.\r\n\r\nSome of the passengers by this particular train were returning from\r\nabroad; but the third-class carriages were the best filled, chiefly with\r\ninsignificant persons of various occupations and degrees, picked up at\r\nthe different stations nearer town. All of them seemed weary, and\r\nmost of them had sleepy eyes and a shivering expr
# ...

# %%
processed_book = preprocess(book)
processed_book
# Out:
# ' produced by martin adamson david widger with corrections by andrew sly the idiot by fyodor dostoyevsky translated by eva martin part i i. towards the end of november during a thaw at nine o clock one morning a train on the warsaw and petersburg railway was approaching the latter city at full speed. the morning was so damp and misty that it was only with great difficulty that the day succeeded in breaking and it was impossible to distinguish anything more than a few yards away from the carriage windows. some of the passengers by this particular train were returning from abroad but the third class carriages were the best filled chiefly with insignificant persons of various occupations and degrees picked up at the different stations nearer town. all of them seemed weary and most of them had sleepy eyes and a shivering expression while their complexions generally appeared to have taken on the colour of the fog outside. when day dawned two passengers in one of the third class carriages 
# ...

# %%
match30 = re.findall(r'the', processed_book)
match30
# Out:
# ['the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
#  'the',
# ...

# %%
#Exercise: Find the number of the pronoun "the" in the corpus. 
match31 = len(re.findall(r'the', processed_book))
match31
# Out:
# 302

# %%
match32 = re.sub(r'\si\s', " I ", processed_book)
match32
# Out:
# ' produced by martin adamson david widger with corrections by andrew sly the idiot by fyodor dostoyevsky translated by eva martin part I i. towards the end of november during a thaw at nine o clock one morning a train on the warsaw and petersburg railway was approaching the latter city at full speed. the morning was so damp and misty that it was only with great difficulty that the day succeeded in breaking and it was impossible to distinguish anything more than a few yards away from the carriage windows. some of the passengers by this particular train were returning from abroad but the third class carriages were the best filled chiefly with insignificant persons of various occupations and degrees picked up at the different stations nearer town. all of them seemed weary and most of them had sleepy eyes and a shivering expression while their complexions generally appeared to have taken on the colour of the fog outside. when day dawned two passengers in one of the third class carriages 
# ...

# %%
#Exercise: Find the number of times anyone was quoted ("") in the corpus.
len(re.findall(r'\”', book))
# Out:
# 0

# %%
#What are the words connected by '--' in the corpus?
match33 = re.findall(r'\w+\--\w+', book)
match33
# Out:
# ['ironical--it',
#  'malicious--smile',
#  'fur--or',
#  'astrachan--overcoat',
#  'it--the',
#  'Italy--was',
#  'malady--a',
#  'money--and',
#  'little--to',
#  'No--Mr',
#  'is--where',
#  'I--I',
#  'I--â',
#  'crime--we',
#  'or--judge',
#  'gaiters--still',
#  'through--well',
#  'say--through',
#  'however--and',
#  'Epanchin--oh',
#  'too--at',
#  'was--and',
#  'Andreevitch--that',
#  'everyone--that',
#  'reduce--or',
#  'raise--to',
#  'listen--and',
#  'history--but',
#  'individual--one',
#  'yes--I',
#  'but--â',
#  't--not',
#  'me--then',
#  'perhaps--â',
#  'Yes--those',
#  'me--is',
#  'servility--if',
#  'Rogojin--hereditary',
#  'citizen--who',
#  'least--goodness',
#  'memory--but',
#  'latter--since',
#  'Rogojin--hung',
#  'him--I',
#  'anything--sheâ',
#  'old--and',
#  'you--scarecrow',
#  'certainly--certainly',
#  'father--I',
#  'Barashkoff--I',
#  'see--and',
#  'everything--Lebedeff',
#  'about--heâ',
#  'now--I',
#  'Lihachof--â',
# ...

# %%
len(match33)
# Out:
# 66
