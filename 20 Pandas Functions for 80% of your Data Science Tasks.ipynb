# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/Admin/pandas/popular-baby-names-1.csv')

# %%
df
# Out:
#        Year of Birth  Gender                   Ethnicity Child's First Name  \
# 0               2011  FEMALE  ASIAN AND PACIFIC ISLANDER             SOPHIA
# 1               2011  FEMALE  ASIAN AND PACIFIC ISLANDER              CHLOE
# 2               2011  FEMALE  ASIAN AND PACIFIC ISLANDER              EMILY
# 3               2011  FEMALE  ASIAN AND PACIFIC ISLANDER             OLIVIA
# 4               2011  FEMALE  ASIAN AND PACIFIC ISLANDER               EMMA
# ...              ...     ...                         ...                ...
# 11340           2016  FEMALE          BLACK NON HISPANIC            Saniyah
# 11341           2016  FEMALE          BLACK NON HISPANIC               Skye
# 11342           2016  FEMALE          BLACK NON HISPANIC              Tiana
# 11343           2016  FEMALE          BLACK NON HISPANIC             Violet
# 11344           2016  FEMALE          BLACK NON HISPANIC              Zahra
#
#        Count  Rank
# 0        119     1
# 1        106     2
# 2         93     3
# 3         89     4
# 4         75     5
# ...      ...   ...
# 11340     10    43
# 11341     10    43
# 11342     10    43
# 11343     10    43
# 11344     10    43
#
# [11345 rows x 6 columns]

# %% [markdown]
# the first row as the header, the first column as an index and replacing N/A with NaN.

# %%
df_2 = pd.read_csv('C:/Users/Admin/pandas/popular-baby-names-1.csv', header=0, index_col=0, na_values='N/A')

# %%
df_2
# Out:
#                Gender                   Ethnicity Child's First Name  Count  \
# Year of Birth
# 2011           FEMALE  ASIAN AND PACIFIC ISLANDER             SOPHIA    119
# 2011           FEMALE  ASIAN AND PACIFIC ISLANDER              CHLOE    106
# 2011           FEMALE  ASIAN AND PACIFIC ISLANDER              EMILY     93
# 2011           FEMALE  ASIAN AND PACIFIC ISLANDER             OLIVIA     89
# 2011           FEMALE  ASIAN AND PACIFIC ISLANDER               EMMA     75
# ...               ...                         ...                ...    ...
# 2016           FEMALE          BLACK NON HISPANIC            Saniyah     10
# 2016           FEMALE          BLACK NON HISPANIC               Skye     10
# 2016           FEMALE          BLACK NON HISPANIC              Tiana     10
# 2016           FEMALE          BLACK NON HISPANIC             Violet     10
# 2016           FEMALE          BLACK NON HISPANIC              Zahra     10
#
#                Rank
# Year of Birth
# 2011              1
# 2011              2
# 2011              3
# 2011              4
# 2011              5
# ...             ...
# 2016             43
# 2016             43
# 2016             43
# 2016             43
# 2016             43
#
# [11345 rows x 5 columns]

# %% [markdown]
# 2. df.describe()
# The df.describe() method in pandas is used to generate summary statistics of various features of a DataFrame. It returns a new DataFrame that contains the count, mean, standard deviation, minimum, 25th percentile, median, 75th percentile, and maximum of each numerical column in the original DataFrame.

# %%
df.describe()
# Out:
#        Year of Birth         Count          Rank
# count   11345.000000  11345.000000  11345.000000
# mean     2013.552578     32.836844     57.656765
# std         1.746367     36.981866     25.186882
# min      2011.000000     10.000000      1.000000
# 25%      2012.000000     13.000000     38.000000
# 50%      2014.000000     20.000000     59.000000
# 75%      2015.000000     35.000000     79.000000
# max      2016.000000    387.000000    102.000000

# %% [markdown]
# A sample with a standard deviation equal to 5 indicates that, on average, the distance between each data point in an entire dataset is different from the mean of the dataset by a value of 5.

# %% [markdown]
# Low standard deviation means data are clustered around the mean, and high standard deviation indicates data are more spread out. A standard deviation close to zero indicates that data points are close to the mean, whereas a high or low standard deviation indicates data points are respectively above or below the mean.

# %%
df.describe(include='all')  # include all columns. Categorical values od not have certain values.
# Out:
#         Year of Birth  Gender           Ethnicity Child's First Name  \
# count    11345.000000   11345               11345              11345
# unique            NaN       2                   7               3016
# top               NaN  FEMALE  WHITE NON HISPANIC              Avery
# freq              NaN    5806                3365                 24
# mean      2013.552578     NaN                 NaN                NaN
# std          1.746367     NaN                 NaN                NaN
# min       2011.000000     NaN                 NaN                NaN
# 25%       2012.000000     NaN                 NaN                NaN
# 50%       2014.000000     NaN                 NaN                NaN
# 75%       2015.000000     NaN                 NaN                NaN
# max       2016.000000     NaN                 NaN                NaN
#
#                Count          Rank
# count   11345.000000  11345.000000
# unique           NaN           NaN
# top              NaN           NaN
# freq             NaN           NaN
# mean       32.836844     57.656765
# std        36.981866     25.186882
# min        10.000000      1.000000
# 25%        13.000000     38.000000
# 50%        20.000000     59.000000
# 75%        35.000000     79.000000
# max       387.000000    102.000000

# %%
df.describe(exclude='number') # exclude numerical columns
# Out:
#         Gender           Ethnicity Child's First Name
# count    11345               11345              11345
# unique       2                   7               3016
# top     FEMALE  WHITE NON HISPANIC              Avery
# freq      5806                3365                 24

# %% [markdown]
# 3. df.info()
# df.info() is a method in pandas that is used to get a concise summary of the DataFrame, including the number of non-null values in each column, the data types of each column, and the memory usage of the DataFrame.

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11345 entries, 0 to 11344
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year of Birth       11345 non-null  int64
#  1   Gender              11345 non-null  object
#  2   Ethnicity           11345 non-null  object
#  3   Child's First Name  11345 non-null  object
#  4   Count               11345 non-null  int64
#  5   Rank                11345 non-null  int64
# dtypes: int64(3), object(3)
# memory usage: 531.9+ KB
# None

# %% [markdown]
# 4. df.plot()
# df.plot() is a method in pandas that is used to create various types of plots from a DataFrame. By default, it creates a line plot of all numerical columns in the DataFrame. But you can also pass the argument kind to specify the type of plot you want to create. Available options are line, bar, barh, hist, box, kde, density, area, pie, scatter, and hexbin.
#
# In the examples below I will use the .plot() method to plot numerical and categorical variables. For the categorical variable, I will plot bar and pie plots and for the numerical variable, I will plot box plots. You can try a different types of plots by yourself.

# %%
df['Gender'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['Gender'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Gender'>

# %%
df['Count'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %% [markdown]
# 5. df.iloc()
# Pandas’ .iloc() function is used to select rows and columns by their integer-based index in a DataFrame. It is used to select rows and columns by their integer-based location.

# %% [markdown]
# # The main distinction between loc and iloc is: loc is label-based, which means that you have to specify rows and columns based on their row and column labels (Names). iloc is integer position-based, so you have to specify rows and columns by their integer position values (0-based integer position).

# %%
# Select the first row
print(df.iloc[0])
# Out:
# Year of Birth                               2011
# Gender                                    FEMALE
# Ethnicity             ASIAN AND PACIFIC ISLANDER
# Child's First Name                        SOPHIA
# Count                                        119
# Rank                                           1
# Name: 0, dtype: object

# %%
# Select the first two rows
print(df.iloc[:2])
# Out:
#    Year of Birth  Gender                   Ethnicity Child's First Name  \
# 0           2011  FEMALE  ASIAN AND PACIFIC ISLANDER             SOPHIA
# 1           2011  FEMALE  ASIAN AND PACIFIC ISLANDER              CHLOE
#
#    Count  Rank
# 0    119     1
# 1    106     2

# %%
# Select the first column
print(df.iloc[:, 0])
# Out:
# 0        2011
# 1        2011
# 2        2011
# 3        2011
# 4        2011
#          ...
# 11340    2016
# 11341    2016
# 11342    2016
# 11343    2016
# 11344    2016
# Name: Year of Birth, Length: 11345, dtype: int64

# %%
# Select the first two columns
print(df.iloc[:, :2])
# Out:
#        Year of Birth  Gender
# 0               2011  FEMALE
# 1               2011  FEMALE
# 2               2011  FEMALE
# 3               2011  FEMALE
# 4               2011  FEMALE
# ...              ...     ...
# 11340           2016  FEMALE
# 11341           2016  FEMALE
# 11342           2016  FEMALE
# 11343           2016  FEMALE
# 11344           2016  FEMALE
#
# [11345 rows x 2 columns]

# %%
# Select the (1, 3) element
print(df.iloc[1, 3])
# Out:
# CHLOE

# %%
#the last value of the iloc range is exclusive. 
df.iloc[0:10,0:3]
# Out:
#    Year of Birth  Gender                   Ethnicity
# 0           2011  FEMALE  ASIAN AND PACIFIC ISLANDER
# 1           2011  FEMALE  ASIAN AND PACIFIC ISLANDER
# 2           2011  FEMALE  ASIAN AND PACIFIC ISLANDER
# 3           2011  FEMALE  ASIAN AND PACIFIC ISLANDER
# 4           2011  FEMALE  ASIAN AND PACIFIC ISLANDER
# 5           2011  FEMALE  ASIAN AND PACIFIC ISLANDER
# 6           2011  FEMALE  ASIAN AND PACIFIC ISLANDER
# 7           2011  FEMALE  ASIAN AND PACIFIC ISLANDER
# 8           2011  FEMALE  ASIAN AND PACIFIC ISLANDER
# 9           2011  FEMALE  ASIAN AND PACIFIC ISLANDER

# %% [markdown]
# 6. df.loc()
# Pandas’ .loc() function is used to select rows and columns by their label-based index in a DataFrame. It is used to select rows and columns by their label-based location.

# %%
# Select the column name 'Gender'
print(df.loc[:,'Gender'])
# Out:
# 0        FEMALE
# 1        FEMALE
# 2        FEMALE
# 3        FEMALE
# 4        FEMALE
#           ...
# 11340    FEMALE
# 11341    FEMALE
# 11342    FEMALE
# 11343    FEMALE
# 11344    FEMALE
# Name: Gender, Length: 11345, dtype: object

# %%
# Select the column name 'Gender'. All columns in between. 
print(df.loc[0:30,'Year of Birth':'Ethnicity'])
# Out:
#     Year of Birth  Gender                   Ethnicity
# 0            2011  FEMALE  ASIAN AND PACIFIC ISLANDER
# 1            2011  FEMALE  ASIAN AND PACIFIC ISLANDER
# 2            2011  FEMALE  ASIAN AND PACIFIC ISLANDER
# 3            2011  FEMALE  ASIAN AND PACIFIC ISLANDER
# 4            2011  FEMALE  ASIAN AND PACIFIC ISLANDER
# 5            2011  FEMALE  ASIAN AND PACIFIC ISLANDER
# 6            2011  FEMALE  ASIAN AND PACIFIC ISLANDER
# 7            2011  FEMALE  ASIAN AND PACIFIC ISLANDER
# 8            2011  FEMALE  ASIAN AND PACIFIC ISLANDER
# 9            2011  FEMALE  ASIAN AND PACIFIC ISLANDER
# 10           2011  FEMALE  ASIAN AND PACIFIC ISLANDER
# 11           2011  FEMALE  ASIAN AND PACIFIC ISLANDER
# 12           2011  FEMALE  ASIAN AND PACIFIC ISLANDER
# 13           2011  FEMALE  ASIAN AND PACIFIC ISLANDER
# 14           2011  FEMALE  ASIAN AND PACIFIC ISLANDER
# 15           2011  FEMALE  ASIAN AND PACIFIC ISLANDER
# 16           2011  FEMALE  ASIAN AND PACIFIC ISLANDER
# 17           2011  FEMALE  ASIAN AND PACIFIC ISLANDER
# 18           2011  FEMALE  ASIAN AND PACIFIC ISLANDER
# 19           2011  FEMALE  ASIAN AND PACIFIC ISLANDER
# 20           2011  FEMALE  ASIAN AND PACIFIC ISLANDER
# 21           2011  FEMALE  ASIAN AND PACIFIC ISLANDER
# 22           2011  FEMALE  ASIAN AND PACIFIC ISLANDER
# 23           2011  FEMALE  ASIAN AND PACIFIC ISLANDER
# 24           2011  FEMALE  ASIAN AND PACIFIC ISLANDER
# 25           2011  FEMALE  ASIAN AND PACIFIC ISLANDER
# 26           2011  FEMALE  ASIAN AND PACIFIC ISLANDER
# 27           2011  FEMALE  ASIAN AND PACIFIC ISLANDER
# 28           2011  FEMALE  ASIAN AND PACIFIC ISLANDER
# 29           2011  FEMALE  ASIAN AND PACIFIC ISLANDER
# 30           2011  FEMALE  ASIAN AND PACIFIC ISLANDER

# %%
# Select the column name 'Gender'. Just specific columns. 
print(df.loc[0:30,['Year of Birth','Ethnicity']])
# Out:
#     Year of Birth                   Ethnicity
# 0            2011  ASIAN AND PACIFIC ISLANDER
# 1            2011  ASIAN AND PACIFIC ISLANDER
# 2            2011  ASIAN AND PACIFIC ISLANDER
# 3            2011  ASIAN AND PACIFIC ISLANDER
# 4            2011  ASIAN AND PACIFIC ISLANDER
# 5            2011  ASIAN AND PACIFIC ISLANDER
# 6            2011  ASIAN AND PACIFIC ISLANDER
# 7            2011  ASIAN AND PACIFIC ISLANDER
# 8            2011  ASIAN AND PACIFIC ISLANDER
# 9            2011  ASIAN AND PACIFIC ISLANDER
# 10           2011  ASIAN AND PACIFIC ISLANDER
# 11           2011  ASIAN AND PACIFIC ISLANDER
# 12           2011  ASIAN AND PACIFIC ISLANDER
# 13           2011  ASIAN AND PACIFIC ISLANDER
# 14           2011  ASIAN AND PACIFIC ISLANDER
# 15           2011  ASIAN AND PACIFIC ISLANDER
# 16           2011  ASIAN AND PACIFIC ISLANDER
# 17           2011  ASIAN AND PACIFIC ISLANDER
# 18           2011  ASIAN AND PACIFIC ISLANDER
# 19           2011  ASIAN AND PACIFIC ISLANDER
# 20           2011  ASIAN AND PACIFIC ISLANDER
# 21           2011  ASIAN AND PACIFIC ISLANDER
# 22           2011  ASIAN AND PACIFIC ISLANDER
# 23           2011  ASIAN AND PACIFIC ISLANDER
# 24           2011  ASIAN AND PACIFIC ISLANDER
# 25           2011  ASIAN AND PACIFIC ISLANDER
# 26           2011  ASIAN AND PACIFIC ISLANDER
# 27           2011  ASIAN AND PACIFIC ISLANDER
# 28           2011  ASIAN AND PACIFIC ISLANDER
# 29           2011  ASIAN AND PACIFIC ISLANDER
# 30           2011  ASIAN AND PACIFIC ISLANDER

# %% [markdown]
# 7. df.assign()
# Pandas’ .assign() function is used to add new columns to a DataFrame, based on the computation of existing columns. It allows you to add new columns to a DataFrame without modifying the original dataframe. The function returns a new DataFrame with the added columns.

# %%
df_new = df.assign(count_plus_5=df['Count'] + 5)
df_new.head()
# Out:
#    Year of Birth  Gender                   Ethnicity Child's First Name  \
# 0           2011  FEMALE  ASIAN AND PACIFIC ISLANDER             SOPHIA
# 1           2011  FEMALE  ASIAN AND PACIFIC ISLANDER              CHLOE
# 2           2011  FEMALE  ASIAN AND PACIFIC ISLANDER              EMILY
# 3           2011  FEMALE  ASIAN AND PACIFIC ISLANDER             OLIVIA
# 4           2011  FEMALE  ASIAN AND PACIFIC ISLANDER               EMMA
#
#    Count  Rank  count_plus_5
# 0    119     1           124
# 1    106     2           111
# 2     93     3            98
# 3     89     4            94
# 4     75     5            80

# %% [markdown]
# 8. df.query()
# Pandas’ .query() function allows you to filter a DataFrame based on a Boolean expression. It allows you to select rows from a DataFrame using a query string similar to SQL. The function returns a new DataFrame containing only the rows that satisfy the Boolean expression.

# %%
# Select rows where age is greater than 30 and income is less than 65000
df_query = df.query('Count > 30 and Rank < 20')
df_query.head()
# Out:
#    Year of Birth  Gender                   Ethnicity Child's First Name  \
# 0           2011  FEMALE  ASIAN AND PACIFIC ISLANDER             SOPHIA
# 1           2011  FEMALE  ASIAN AND PACIFIC ISLANDER              CHLOE
# 2           2011  FEMALE  ASIAN AND PACIFIC ISLANDER              EMILY
# 3           2011  FEMALE  ASIAN AND PACIFIC ISLANDER             OLIVIA
# 4           2011  FEMALE  ASIAN AND PACIFIC ISLANDER               EMMA
#
#    Count  Rank
# 0    119     1
# 1    106     2
# 2     93     3
# 3     89     4
# 4     75     5

# %%
# Select rows where gender is Male
df_query = df.query("Gender == 'MALE'& Ethnicity == 'ASIAN AND PACIFIC ISLANDER'")
df_query.head()
# Out:
#      Year of Birth Gender                   Ethnicity Child's First Name  \
# 993           2011   MALE  ASIAN AND PACIFIC ISLANDER              ETHAN
# 994           2011   MALE  ASIAN AND PACIFIC ISLANDER             JAYDEN
# 995           2011   MALE  ASIAN AND PACIFIC ISLANDER               RYAN
# 996           2011   MALE  ASIAN AND PACIFIC ISLANDER             JUSTIN
# 997           2011   MALE  ASIAN AND PACIFIC ISLANDER              LUCAS
#
#      Count  Rank
# 993    177     1
# 994    173     2
# 995    150     3
# 996    110     4
# 997    103     5

# %%
# Select rows where gender is Male
df_query = df.query("Gender == 'MALE'& Ethnicity == 'ASIAN AND PACIFIC ISLANDER' & Rank < 20")
df_query.head()
# Out:
#      Year of Birth Gender                   Ethnicity Child's First Name  \
# 993           2011   MALE  ASIAN AND PACIFIC ISLANDER              ETHAN
# 994           2011   MALE  ASIAN AND PACIFIC ISLANDER             JAYDEN
# 995           2011   MALE  ASIAN AND PACIFIC ISLANDER               RYAN
# 996           2011   MALE  ASIAN AND PACIFIC ISLANDER             JUSTIN
# 997           2011   MALE  ASIAN AND PACIFIC ISLANDER              LUCAS
#
#      Count  Rank
# 993    177     1
# 994    173     2
# 995    150     3
# 996    110     4
# 997    103     5

# %% [markdown]
# 9. df.sort_values()
# Pandas’ .sort_values() function allows you to sort a DataFrame by one or multiple columns. It sorts the DataFrame based on the values of one or more columns, in ascending or descending order. The function returns a new DataFrame sorted by the specified column(s).

# %%
# Sort by age in ascending order
df_sorted = df.sort_values(by= ['Count','Rank'])
df_sorted.head()
# Out:
#      Year of Birth  Gender                   Ethnicity Child's First Name  \
# 141           2011  FEMALE  ASIAN AND PACIFIC ISLANDER               AIZA
# 142           2011  FEMALE  ASIAN AND PACIFIC ISLANDER              ALEXA
# 143           2011  FEMALE  ASIAN AND PACIFIC ISLANDER             ALISHA
# 144           2011  FEMALE  ASIAN AND PACIFIC ISLANDER              ANGIE
# 145           2011  FEMALE  ASIAN AND PACIFIC ISLANDER          ANNABELLE
#
#      Count  Rank
# 141     10    38
# 142     10    38
# 143     10    38
# 144     10    38
# 145     10    38

# %%
# Sort by income in descending order
df_sorted = df.sort_values(by='Rank', ascending=False)
df_sorted.head()
# Out:
#       Year of Birth Gender           Ethnicity Child's First Name  Count  Rank
# 7236           2014   MALE  WHITE NON HISPANIC              Yidel     10   102
# 7224           2014   MALE  WHITE NON HISPANIC               Erik     10   102
# 7235           2014   MALE  WHITE NON HISPANIC             Shraga     10   102
# 7234           2014   MALE  WHITE NON HISPANIC               Nico     10   102
# 7233           2014   MALE  WHITE NON HISPANIC              Myles     10   102

# %% [markdown]
# RandomState exposes a number of methods for generating random numbers drawn from a variety of probability distributions.

# %% [markdown]
# 0. df.sample()
# Pandas’ .sample() function allows you to randomly select rows from a DataFrame. It returns a new DataFrame containing the randomly selected rows. The function takes several parameters that allow you to control the sampling process, such as the number of rows to return, and whether or not to sample with replacement and seed for reproducibility.

# %%
# Sample 2 rows without replacement
df_sample = df.sample(n=2, replace=False, random_state=16)
df_sample
# Out:
#       Year of Birth  Gender           Ethnicity Child's First Name  Count  \
# 6351           2014  FEMALE  WHITE NON HISPANIC               Alma     11
# 1307           2011    MALE  BLACK NON HISPANIC             JELANI     11
#
#       Rank
# 6351    85
# 1307    63

# %%
import random

random.seed(121)
print(random.random())

random.seed(10)
print(random.random())
# Out:
# 0.08730148686581662
# 0.5714025946899135

# %%
# Sample 3 rows with replacement
df_sample = df.sample(n=3, replace=True, random_state=42)
df_sample
# Out:
#       Year of Birth  Gender           Ethnicity Child's First Name  Count  \
# 7270           2015    MALE            HISPANIC          Christian     97
# 860            2011  FEMALE  WHITE NON HISPANIC              AHUVA     16
# 5390           2013    MALE  WHITE NON HISPANIC            Everett     20
#
#       Rank
# 7270    31
# 860     75
# 5390    90

# %%
#random choice of two columns. All rows. 
df_sample = df.sample(n=2, replace=False, random_state=1, axis=1)
df_sample
# Out:
#                         Ethnicity  Gender
# 0      ASIAN AND PACIFIC ISLANDER  FEMALE
# 1      ASIAN AND PACIFIC ISLANDER  FEMALE
# 2      ASIAN AND PACIFIC ISLANDER  FEMALE
# 3      ASIAN AND PACIFIC ISLANDER  FEMALE
# 4      ASIAN AND PACIFIC ISLANDER  FEMALE
# ...                           ...     ...
# 11340          BLACK NON HISPANIC  FEMALE
# 11341          BLACK NON HISPANIC  FEMALE
# 11342          BLACK NON HISPANIC  FEMALE
# 11343          BLACK NON HISPANIC  FEMALE
# 11344          BLACK NON HISPANIC  FEMALE
#
# [11345 rows x 2 columns]

# %%
df.shape
# Out:
# (11345, 6)

# %%
#random choice of three columns. All rows. 
df_sample = df.sample(n=3, replace=False, random_state=10, axis=1)
df_sample
# Out:
#                         Ethnicity  Rank  Year of Birth
# 0      ASIAN AND PACIFIC ISLANDER     1           2011
# 1      ASIAN AND PACIFIC ISLANDER     2           2011
# 2      ASIAN AND PACIFIC ISLANDER     3           2011
# 3      ASIAN AND PACIFIC ISLANDER     4           2011
# 4      ASIAN AND PACIFIC ISLANDER     5           2011
# ...                           ...   ...            ...
# 11340          BLACK NON HISPANIC    43           2016
# 11341          BLACK NON HISPANIC    43           2016
# 11342          BLACK NON HISPANIC    43           2016
# 11343          BLACK NON HISPANIC    43           2016
# 11344          BLACK NON HISPANIC    43           2016
#
# [11345 rows x 3 columns]

# %% [markdown]
# 11. df.isnull()
# The isnull() method in Pandas returns a DataFrame of the same shape as the original DataFrame, but with True or False values indicating whether each value in the original DataFrame is missing or not. Missing values, such as NaN or None, will be True in the resulting DataFrame, while non-missing values will be False.

# %%
df.isnull()
# Out:
#        Year of Birth  Gender  Ethnicity  Child's First Name  Count   Rank
# 0              False   False      False               False  False  False
# 1              False   False      False               False  False  False
# 2              False   False      False               False  False  False
# 3              False   False      False               False  False  False
# 4              False   False      False               False  False  False
# ...              ...     ...        ...                 ...    ...    ...
# 11340          False   False      False               False  False  False
# 11341          False   False      False               False  False  False
# 11342          False   False      False               False  False  False
# 11343          False   False      False               False  False  False
# 11344          False   False      False               False  False  False
#
# [11345 rows x 6 columns]

# %% [markdown]
# nterpolation with the help of padding simply means filling missing values with the same value present above them in the dataset. If the missing value is in the first row, then this method will not work. While using this technique, you also need to specify the limit, which means how many NaN values to fill

# %% [markdown]
# 2. df.fillna()
# The fillna() method in Pandas is used to fill in missing values in a DataFrame with a specified value or method. By default, it replaces missing values with NaN, but you can specify a different value to use instead as shown below:
#
# value: Specifies the value to use to fill in the missing values. Can be a scalar value or a dict of values for different columns.
# method: Specifies the method to use for filling in missing values. Can be 'ffill' (forward-fill) or 'bfill' (backward-fill) or 'interpolate'(interpolate values) or 'pad' or 'backfill'
# axis: Specifies the axis along which to fill in missing values. It can be 0 (rows) or 1 (columns).
# inplace: Whether to fill in the missing values in place (modifying the original DataFrame) or to return a new DataFrame with the missing values filled in.
# limit: Specifies the maximum number of consecutive missing values to fill.
# downcast: Specifies a dictionary of values to use to downcast the data types of columns.

# %%
# fill missing values with 0
df.fillna(0)
# Out:
#        Year of Birth  Gender                   Ethnicity Child's First Name  \
# 0               2011  FEMALE  ASIAN AND PACIFIC ISLANDER             SOPHIA
# 1               2011  FEMALE  ASIAN AND PACIFIC ISLANDER              CHLOE
# 2               2011  FEMALE  ASIAN AND PACIFIC ISLANDER              EMILY
# 3               2011  FEMALE  ASIAN AND PACIFIC ISLANDER             OLIVIA
# 4               2011  FEMALE  ASIAN AND PACIFIC ISLANDER               EMMA
# ...              ...     ...                         ...                ...
# 11340           2016  FEMALE          BLACK NON HISPANIC            Saniyah
# 11341           2016  FEMALE          BLACK NON HISPANIC               Skye
# 11342           2016  FEMALE          BLACK NON HISPANIC              Tiana
# 11343           2016  FEMALE          BLACK NON HISPANIC             Violet
# 11344           2016  FEMALE          BLACK NON HISPANIC              Zahra
#
#        Count  Rank
# 0        119     1
# 1        106     2
# 2         93     3
# 3         89     4
# 4         75     5
# ...      ...   ...
# 11340     10    43
# 11341     10    43
# 11342     10    43
# 11343     10    43
# 11344     10    43
#
# [11345 rows x 6 columns]

# %%
# fill missing values using interpolation
df.interpolate()
# Out:
#        Year of Birth  Gender                   Ethnicity Child's First Name  \
# 0               2011  FEMALE  ASIAN AND PACIFIC ISLANDER             SOPHIA
# 1               2011  FEMALE  ASIAN AND PACIFIC ISLANDER              CHLOE
# 2               2011  FEMALE  ASIAN AND PACIFIC ISLANDER              EMILY
# 3               2011  FEMALE  ASIAN AND PACIFIC ISLANDER             OLIVIA
# 4               2011  FEMALE  ASIAN AND PACIFIC ISLANDER               EMMA
# ...              ...     ...                         ...                ...
# 11340           2016  FEMALE          BLACK NON HISPANIC            Saniyah
# 11341           2016  FEMALE          BLACK NON HISPANIC               Skye
# 11342           2016  FEMALE          BLACK NON HISPANIC              Tiana
# 11343           2016  FEMALE          BLACK NON HISPANIC             Violet
# 11344           2016  FEMALE          BLACK NON HISPANIC              Zahra
#
#        Count  Rank
# 0        119     1
# 1        106     2
# 2         93     3
# 3         89     4
# 4         75     5
# ...      ...   ...
# 11340     10    43
# 11341     10    43
# 11342     10    43
# 11343     10    43
# 11344     10    43
#
# [11345 rows x 6 columns]

# %%
# forward-fill missing values (propagates last valid observation forward to next)
df.fillna(method='ffill')
# Out:
#        Year of Birth  Gender                   Ethnicity Child's First Name  \
# 0               2011  FEMALE  ASIAN AND PACIFIC ISLANDER             SOPHIA
# 1               2011  FEMALE  ASIAN AND PACIFIC ISLANDER              CHLOE
# 2               2011  FEMALE  ASIAN AND PACIFIC ISLANDER              EMILY
# 3               2011  FEMALE  ASIAN AND PACIFIC ISLANDER             OLIVIA
# 4               2011  FEMALE  ASIAN AND PACIFIC ISLANDER               EMMA
# ...              ...     ...                         ...                ...
# 11340           2016  FEMALE          BLACK NON HISPANIC            Saniyah
# 11341           2016  FEMALE          BLACK NON HISPANIC               Skye
# 11342           2016  FEMALE          BLACK NON HISPANIC              Tiana
# 11343           2016  FEMALE          BLACK NON HISPANIC             Violet
# 11344           2016  FEMALE          BLACK NON HISPANIC              Zahra
#
#        Count  Rank
# 0        119     1
# 1        106     2
# 2         93     3
# 3         89     4
# 4         75     5
# ...      ...   ...
# 11340     10    43
# 11341     10    43
# 11342     10    43
# 11343     10    43
# 11344     10    43
#
# [11345 rows x 6 columns]

# %%
# backward-fill missing values (propagates next valid observation backward to last)
df.fillna(method='bfill')
# Out:
#        Year of Birth  Gender                   Ethnicity Child's First Name  \
# 0               2011  FEMALE  ASIAN AND PACIFIC ISLANDER             SOPHIA
# 1               2011  FEMALE  ASIAN AND PACIFIC ISLANDER              CHLOE
# 2               2011  FEMALE  ASIAN AND PACIFIC ISLANDER              EMILY
# 3               2011  FEMALE  ASIAN AND PACIFIC ISLANDER             OLIVIA
# 4               2011  FEMALE  ASIAN AND PACIFIC ISLANDER               EMMA
# ...              ...     ...                         ...                ...
# 11340           2016  FEMALE          BLACK NON HISPANIC            Saniyah
# 11341           2016  FEMALE          BLACK NON HISPANIC               Skye
# 11342           2016  FEMALE          BLACK NON HISPANIC              Tiana
# 11343           2016  FEMALE          BLACK NON HISPANIC             Violet
# 11344           2016  FEMALE          BLACK NON HISPANIC              Zahra
#
#        Count  Rank
# 0        119     1
# 1        106     2
# 2         93     3
# 3         89     4
# 4         75     5
# ...      ...   ...
# 11340     10    43
# 11341     10    43
# 11342     10    43
# 11343     10    43
# 11344     10    43
#
# [11345 rows x 6 columns]

# %% [markdown]
# It is important to note that the fillna() method returns a new DataFrame with the missing values filled in and does not modify the original DataFrame in place. If you want to modify the original DataFrame, you can use the inplace parameter and set it to True.

# %%
# fill missing values in place
df.fillna(0, inplace=True)

# %%
df.isnull().sum()
# Out:
# Year of Birth         0
# Gender                0
# Ethnicity             0
# Child's First Name    0
# Count                 0
# Rank                  0
# dtype: int64

# %% [markdown]
# source: https://towardsdatascience.com/how-to-fill-missing-data-with-pandas-8cb875362a0d

# %%
df = pd.DataFrame({'date':['2021-01-01', '2021-01-02', '2021-01-03', '2021-01-04','2021-01-01', '2021-01-02', '2021-01-03', '2021-01-04'], 'fruit':['apple', 'apple', 'apple', 'apple', 'mango', 'mango', 'mango', 'mango'], 'price': [0.80, None, None, 1.20, None, 2.10, 2.00, 1.80]})
df['date'] = pd.to_datetime(df['date'])

# %%
df
# Out:
#         date  fruit  price
# 0 2021-01-01  apple    0.8
# 1 2021-01-02  apple    NaN
# 2 2021-01-03  apple    NaN
# 3 2021-01-04  apple    1.2
# 4 2021-01-01  mango    NaN
# 5 2021-01-02  mango    2.1
# 6 2021-01-03  mango    2.0
# 7 2021-01-04  mango    1.8

# %% [markdown]
# Methods
# Fill with Constant Value

# %%
#inplace true is to create a nre dataset. 
df['price'].fillna(value = 0.85, inplace = True)

# %%
df
# Out:
#         date  fruit  price
# 0 2021-01-01  apple   0.80
# 1 2021-01-02  apple   0.85
# 2 2021-01-03  apple   0.85
# 3 2021-01-04  apple   1.20
# 4 2021-01-01  mango   0.85
# 5 2021-01-02  mango   2.10
# 6 2021-01-03  mango   2.00
# 7 2021-01-04  mango   1.80

# %% [markdown]
# Fill with Mean / Median of Column

# %%
# mean
df['price'].fillna(value = df.price.mean(), inplace = True)
# median
df['price'].fillna(value = df.price.median(), inplace = True)

# %% [markdown]
# Fill with Mean / Median of Group
# We can fill the missing values using group level statistics in the following manner.
# the group by is not as the general mean because the mean is extract first by category.

# %%
# mean
df['price'].fillna(df.groupby('fruit')['price'].transform('mean'), inplace = True)
# median
df['price'].fillna(df.groupby('fruit')['price'].transform('median'), inplace = True)

# %%
df
# Out:
#         date  fruit  price
# 0 2021-01-01  apple   0.80
# 1 2021-01-02  apple   0.85
# 2 2021-01-03  apple   0.85
# 3 2021-01-04  apple   1.20
# 4 2021-01-01  mango   0.85
# 5 2021-01-02  mango   2.10
# 6 2021-01-03  mango   2.00
# 7 2021-01-04  mango   1.80

# %% [markdown]
# the explanation is that the Nan values in apple will be filled by the median of apple, mango with the median of mango ans so on..

# %% [markdown]
# Forward Fill
# Forward fill, also known as “ffill” in short, propagates the last valid observation forward along the selected axis of the DataFrame (down the column in our example).

# %%
df
# Out:
#         date  fruit  price
# 0 2021-01-01  apple    0.8
# 1 2021-01-02  apple    NaN
# 2 2021-01-03  apple    NaN
# 3 2021-01-04  apple    1.2
# 4 2021-01-01  mango    NaN
# 5 2021-01-02  mango    2.1
# 6 2021-01-03  mango    2.0
# 7 2021-01-04  mango    1.8

# %%
df['price'].fillna(method = 'ffill', inplace = True)

# %%
df
# Out:
#         date  fruit  price
# 0 2021-01-01  apple    0.8
# 1 2021-01-02  apple    0.8
# 2 2021-01-03  apple    0.8
# 3 2021-01-04  apple    1.2
# 4 2021-01-01  mango    1.2
# 5 2021-01-02  mango    2.1
# 6 2021-01-03  mango    2.0
# 7 2021-01-04  mango    1.8

# %%
df
# Out:
#         date  fruit  price
# 0 2021-01-01  apple    0.8
# 1 2021-01-02  apple    NaN
# 2 2021-01-03  apple    NaN
# 3 2021-01-04  apple    1.2
# 4 2021-01-01  mango    NaN
# 5 2021-01-02  mango    2.1
# 6 2021-01-03  mango    2.0
# 7 2021-01-04  mango    1.8

# %%
df['price'].fillna(method = 'ffill', limit = 1, inplace = False)
# Out:
# 0    0.8
# 1    0.8
# 2    NaN
# 3    1.2
# 4    1.2
# 5    2.1
# 6    2.0
# 7    1.8
# Name: price, dtype: float64

# %%
df['price'].fillna(method = 'bfill', inplace = False)
# Out:
# 0    0.8
# 1    1.2
# 2    1.2
# 3    1.2
# 4    2.1
# 5    2.1
# 6    2.0
# 7    1.8
# Name: price, dtype: float64

# %%
df['price'].fillna(method = 'bfill', limit = 1, inplace = False)
# Out:
# 0    0.8
# 1    NaN
# 2    1.2
# 3    1.2
# 4    2.1
# 5    2.1
# 6    2.0
# 7    1.8
# Name: price, dtype: float64

# %%
# backfill without propagation limit
df['price'] = df.groupby('fruit')['price'].bfill()

# %%
df
# Out:
#         date  fruit  price
# 0 2021-01-01  apple    0.8
# 1 2021-01-02  apple    1.2
# 2 2021-01-03  apple    1.2
# 3 2021-01-04  apple    1.2
# 4 2021-01-01  mango    2.1
# 5 2021-01-02  mango    2.1
# 6 2021-01-03  mango    2.0
# 7 2021-01-04  mango    1.8

# %%
df['price'].interpolate(method = 'linear', inplace = False)
# Out:
# 0    0.8
# 1    1.2
# 2    1.2
# 3    1.2
# 4    2.1
# 5    2.1
# 6    2.0
# 7    1.8
# Name: price, dtype: float64

# %%
df['price'] = df.groupby('fruit')['price'].apply(lambda x: x.interpolate(method='linear'))

# %% [markdown]
# Fill value based on conditions

# %%
df['weekday'] = df['date'].apply(lambda x: False if x.day_name() in ['Saturday', 'Sunday'] else True)

# %%
df['weekday']
# Out:
# 0     True
# 1    False
# 2    False
# 3     True
# 4     True
# 5    False
# 6    False
# 7     True
# Name: weekday, dtype: bool

# %%
mean_price = df.groupby('fruit')['price'].transform('mean')
mean_price
# Out:
# 0    1.000000
# 1    1.000000
# 2    1.000000
# 3    1.000000
# 4    1.966667
# 5    1.966667
# 6    1.966667
# 7    1.966667
# Name: price, dtype: float64

# %%
df['price'].fillna((mean_price).where(cond = df.weekday, other = mean_price*1.25), inplace = True)

# %%
df
# Out:
#         date  fruit     price  weekday
# 0 2021-01-01  apple  0.800000     True
# 1 2021-01-02  apple  1.250000    False
# 2 2021-01-03  apple  1.250000    False
# 3 2021-01-04  apple  1.200000     True
# 4 2021-01-01  mango  1.966667     True
# 5 2021-01-02  mango  2.100000    False
# 6 2021-01-03  mango  2.000000    False
# 7 2021-01-04  mango  1.800000     True

# %% [markdown]
# 13. df.dropna()
# df.dropna() is a method used in the Pandas library to remove missing or null values from a DataFrame. It removes rows or columns from the DataFrame where at least one element is missing.
#
# You can remove all rows containing at least one missing value by calling df.dropna().

# %%
df.isnull().sum()
# Out:
# Year of Birth         0
# Gender                0
# Ethnicity             0
# Child's First Name    0
# Count                 0
# Rank                  0
# dtype: int64

# %% [markdown]
# No changes because there are not null values.

# %%
df.dropna()
# Out:
#        Year of Birth  Gender                   Ethnicity Child's First Name  \
# 0               2011  FEMALE  ASIAN AND PACIFIC ISLANDER             SOPHIA
# 1               2011  FEMALE  ASIAN AND PACIFIC ISLANDER              CHLOE
# 2               2011  FEMALE  ASIAN AND PACIFIC ISLANDER              EMILY
# 3               2011  FEMALE  ASIAN AND PACIFIC ISLANDER             OLIVIA
# 4               2011  FEMALE  ASIAN AND PACIFIC ISLANDER               EMMA
# ...              ...     ...                         ...                ...
# 11340           2016  FEMALE          BLACK NON HISPANIC            Saniyah
# 11341           2016  FEMALE          BLACK NON HISPANIC               Skye
# 11342           2016  FEMALE          BLACK NON HISPANIC              Tiana
# 11343           2016  FEMALE          BLACK NON HISPANIC             Violet
# 11344           2016  FEMALE          BLACK NON HISPANIC              Zahra
#
#        Count  Rank
# 0        119     1
# 1        106     2
# 2         93     3
# 3         89     4
# 4         75     5
# ...      ...   ...
# 11340     10    43
# 11341     10    43
# 11342     10    43
# 11343     10    43
# 11344     10    43
#
# [11345 rows x 6 columns]

# %% [markdown]
# If you want to remove only the columns that contain at least one missing value you can use df.dropna(axis=1)

# %%
df.dropna(axis=1)
# Out:
#        Year of Birth  Gender                   Ethnicity Child's First Name  \
# 0               2011  FEMALE  ASIAN AND PACIFIC ISLANDER             SOPHIA
# 1               2011  FEMALE  ASIAN AND PACIFIC ISLANDER              CHLOE
# 2               2011  FEMALE  ASIAN AND PACIFIC ISLANDER              EMILY
# 3               2011  FEMALE  ASIAN AND PACIFIC ISLANDER             OLIVIA
# 4               2011  FEMALE  ASIAN AND PACIFIC ISLANDER               EMMA
# ...              ...     ...                         ...                ...
# 11340           2016  FEMALE          BLACK NON HISPANIC            Saniyah
# 11341           2016  FEMALE          BLACK NON HISPANIC               Skye
# 11342           2016  FEMALE          BLACK NON HISPANIC              Tiana
# 11343           2016  FEMALE          BLACK NON HISPANIC             Violet
# 11344           2016  FEMALE          BLACK NON HISPANIC              Zahra
#
#        Count  Rank
# 0        119     1
# 1        106     2
# 2         93     3
# 3         89     4
# 4         75     5
# ...      ...   ...
# 11340     10    43
# 11341     10    43
# 11342     10    43
# 11343     10    43
# 11344     10    43
#
# [11345 rows x 6 columns]

# %% [markdown]
# You can also set thresh parameter to keep only the rows/columns that have at least thresh non-NA/null values.

# %%
#if it has 1 or 2 nan values the rows or columns are kept.  
df.dropna(thresh=2)

# %% [markdown]
# 14. df.drop()
# df.drop() is a method used in the Pandas library to remove rows or columns from a DataFrame by specifying the corresponding labels. It can be used to drop one or multiple rows or columns based on their labels.
#
# You can remove a specific row by calling df.drop() and passing the index label of the row you want to remove, and the axis parameter set to 0 (default is 0)

# %%
df.drop(0)
# Out:
#        Year of Birth  Gender                   Ethnicity Child's First Name  \
# 1               2011  FEMALE  ASIAN AND PACIFIC ISLANDER              CHLOE
# 2               2011  FEMALE  ASIAN AND PACIFIC ISLANDER              EMILY
# 3               2011  FEMALE  ASIAN AND PACIFIC ISLANDER             OLIVIA
# 4               2011  FEMALE  ASIAN AND PACIFIC ISLANDER               EMMA
# 5               2011  FEMALE  ASIAN AND PACIFIC ISLANDER           ISABELLA
# ...              ...     ...                         ...                ...
# 11340           2016  FEMALE          BLACK NON HISPANIC            Saniyah
# 11341           2016  FEMALE          BLACK NON HISPANIC               Skye
# 11342           2016  FEMALE          BLACK NON HISPANIC              Tiana
# 11343           2016  FEMALE          BLACK NON HISPANIC             Violet
# 11344           2016  FEMALE          BLACK NON HISPANIC              Zahra
#
#        Count  Rank
# 1        106     2
# 2         93     3
# 3         89     4
# 4         75     5
# 5         67     6
# ...      ...   ...
# 11340     10    43
# 11341     10    43
# 11342     10    43
# 11343     10    43
# 11344     10    43
#
# [11344 rows x 6 columns]

# %%
df.drop([0,1])
# Out:
#        Year of Birth  Gender                   Ethnicity Child's First Name  \
# 2               2011  FEMALE  ASIAN AND PACIFIC ISLANDER              EMILY
# 3               2011  FEMALE  ASIAN AND PACIFIC ISLANDER             OLIVIA
# 4               2011  FEMALE  ASIAN AND PACIFIC ISLANDER               EMMA
# 5               2011  FEMALE  ASIAN AND PACIFIC ISLANDER           ISABELLA
# 6               2011  FEMALE  ASIAN AND PACIFIC ISLANDER            TIFFANY
# ...              ...     ...                         ...                ...
# 11340           2016  FEMALE          BLACK NON HISPANIC            Saniyah
# 11341           2016  FEMALE          BLACK NON HISPANIC               Skye
# 11342           2016  FEMALE          BLACK NON HISPANIC              Tiana
# 11343           2016  FEMALE          BLACK NON HISPANIC             Violet
# 11344           2016  FEMALE          BLACK NON HISPANIC              Zahra
#
#        Count  Rank
# 2         93     3
# 3         89     4
# 4         75     5
# 5         67     6
# 6         54     7
# ...      ...   ...
# 11340     10    43
# 11341     10    43
# 11342     10    43
# 11343     10    43
# 11344     10    43
#
# [11343 rows x 6 columns]

# %%
df.drop(['Count', 'Rank'], axis=1)
# Out:
#        Year of Birth  Gender                   Ethnicity Child's First Name
# 0               2011  FEMALE  ASIAN AND PACIFIC ISLANDER             SOPHIA
# 1               2011  FEMALE  ASIAN AND PACIFIC ISLANDER              CHLOE
# 2               2011  FEMALE  ASIAN AND PACIFIC ISLANDER              EMILY
# 3               2011  FEMALE  ASIAN AND PACIFIC ISLANDER             OLIVIA
# 4               2011  FEMALE  ASIAN AND PACIFIC ISLANDER               EMMA
# ...              ...     ...                         ...                ...
# 11340           2016  FEMALE          BLACK NON HISPANIC            Saniyah
# 11341           2016  FEMALE          BLACK NON HISPANIC               Skye
# 11342           2016  FEMALE          BLACK NON HISPANIC              Tiana
# 11343           2016  FEMALE          BLACK NON HISPANIC             Violet
# 11344           2016  FEMALE          BLACK NON HISPANIC              Zahra
#
# [11345 rows x 4 columns]

# %% [markdown]
# 15. pd.pivot_table()
# pd.pivot_table() is a method in the Pandas library that is used to create a pivot table from a DataFrame. A pivot table is a table that summarizes and aggregates data in a more meaningful and organized way, by creating a new table with one or more columns as the index, one or more columns as values, and one or more columns as attributes.

# %%
pivot_table = pd.pivot_table(df, index='Ethnicity', values='Count', aggfunc='sum')
pivot_table.head()
# Out:
#                              Count
# Ethnicity
# ASIAN AND PACI                9185
# ASIAN AND PACIFIC ISLANDER   41500
# BLACK NON HISP                8802
# BLACK NON HISPANIC           45179
# HISPANIC                    122805

# %%
#count get the same values and each time its 
pivot_table = pd.pivot_table(df, index=['Ethnicity','Gender'], values= 'Count' , aggfunc=['sum','mean'])
pivot_table.head(20)
# Out:
#                                      sum       mean
#                                    Count      Count
# Ethnicity                  Gender
# ASIAN AND PACI             FEMALE   4072  23.812865
#                            MALE     5113  31.176829
# ASIAN AND PACIFIC ISLANDER FEMALE  18033  21.805320
#                            MALE    23467  28.104192
# BLACK NON HISP             FEMALE   3693  23.226415
#                            MALE     5109  30.230769
# BLACK NON HISPANIC         FEMALE  19288  22.745283
#                            MALE    25891  30.246495
# HISPANIC                   FEMALE  52225  30.648474
#                            MALE    70580  43.838509
# WHITE NON HISP             FEMALE  10954  32.123167
#                            MALE    12850  43.412162
# WHITE NON HISPANIC         FEMALE  56700  32.289294
#                            MALE    64559  40.123679

# %%
#count get the same values and each time its 
pivot_table = pd.pivot_table(df, index=['Year of Birth','Ethnicity','Gender'], values= 'Count', aggfunc=['sum'])
pivot_table.head(20)
# Out:
#                                                    sum
#                                                  Count
# Year of Birth Ethnicity                  Gender
# 2011          ASIAN AND PACIFIC ISLANDER FEMALE   3383
#                                          MALE     4645
#               BLACK NON HISPANIC         FEMALE   4349
#                                          MALE     6073
#               HISPANIC                   FEMALE  10344
#                                          MALE    13073
#               WHITE NON HISPANIC         FEMALE  11163
#                                          MALE    13027
# 2012          ASIAN AND PACI             FEMALE   4072
#                                          MALE     5113
#               BLACK NON HISP             FEMALE   3693
#                                          MALE     5109
#               HISPANIC                   FEMALE   8524
#                                          MALE    11617
#               WHITE NON HISP             FEMALE  10954
#                                          MALE    12850
# 2013          ASIAN AND PACIFIC ISLANDER FEMALE   3025
#                                          MALE     3856
#               BLACK NON HISPANIC         FEMALE   3507
#                                          MALE     4609

# %% [markdown]
# 16. df.groupby()df.groupby() is a method in the Pandas library that is used to group rows of a DataFrame based on one or multiple columns. This allows you to perform aggregate operations on the groups, such as calculating the mean, sum, or count of the values in each group.
#
# df.groupby() returns a GroupBy object, which you can then use to perform various operations on the groups, such as calculating the sum, mean, or count of the values in each group.

# %%
grouped = df.groupby('Gender')
# Print the mean of each group
print(grouped.mean())
# Out:
#         Year of Birth      Count       Rank
# Gender
# FEMALE    2013.547365  28.412849  52.509128
# MALE      2013.558043  37.474093  63.052537

# %%
grouped = df.groupby(['Gender', 'Ethnicity'])

# Print the sum of each group
print(grouped.sum())
# Out:
#                                    Year of Birth  Count    Rank
# Gender Ethnicity
# FEMALE ASIAN AND PACI                     344052   4072    5741
#        ASIAN AND PACIFIC ISLANDER        1665515  18033   25529
#        BLACK NON HISP                     319908   3693    5516
#        BLACK NON HISPANIC                1707706  19288   26878
#        HISPANIC                          3430969  52225  103488
#        WHITE NON HISP                     686092  10954   22414
#        WHITE NON HISPANIC                3536414  56700  115302
# MALE   ASIAN AND PACI                     329968   5113    7383
#        ASIAN AND PACIFIC ISLANDER        1681670  23467   35389
#        BLACK NON HISP                     340028   5109    7528
#        BLACK NON HISPANIC                1723760  25891   38857
#        HISPANIC                          3241744  70580  117006
#        WHITE NON HISP                     595552  12850   20932
#        WHITE NON HISPANIC                3240376  64559  122153

# %% [markdown]
# 17. df.transpose()
# df.transpose() is a method in the Pandas library used to transpose the rows and columns of a DataFrame? This means that the rows become columns and the columns become rows.

# %%
# Transpose the DataFrame
df_transposed = df.transpose()

# Print the transposed DataFrame
df_transposed.head()
# Out:
#                                          0                           1      \
# Year of Birth                             2011                        2011
# Gender                                  FEMALE                      FEMALE
# Ethnicity           ASIAN AND PACIFIC ISLANDER  ASIAN AND PACIFIC ISLANDER
# Child's First Name                      SOPHIA                       CHLOE
# Count                                      119                         106
#
#                                          2                           3      \
# Year of Birth                             2011                        2011
# Gender                                  FEMALE                      FEMALE
# Ethnicity           ASIAN AND PACIFIC ISLANDER  ASIAN AND PACIFIC ISLANDER
# Child's First Name                       EMILY                      OLIVIA
# Count                                       93                          89
#
#                                          4                           5      \
# Year of Birth                             2011                        2011
# Gender                                  FEMALE                      FEMALE
# Ethnicity           ASIAN AND PACIFIC ISLANDER  ASIAN AND PACIFIC ISLANDER
# Child's First Name                        EMMA                    ISABELLA
# Count                                       75                          67
#
#                                          6                           7      \
# Year of Birth                             2011                        2011
# Gender                                  FEMALE                      FEMALE
# Ethnicity           ASIAN AND PACIFIC ISLANDER  ASIAN AND PACIFIC ISLANDER
# Child's First Name                     TIFFANY                      ASHLEY
# Count                                       54                          52
#
#                                          8                           9      \
# Year of Birth                             2011                        2011
# Gender                                  FEMALE                      FEMALE
# Ethnicity           ASIAN AND PACIFIC ISLANDER  ASIAN AND PACIFIC ISLANDER
# Child's First Name                       FIONA                      ANGELA
# Count                                       48                          47
#
#                     ...               11335               11336  \
# Year of Birth       ...                2016                2016
# Gender              ...              FEMALE              FEMALE
# Ethnicity           ...  BLACK NON HISPANIC  BLACK NON HISPANIC
# Child's First Name  ...             Mikayla                Mila
# Count               ...                  10                  10
#
#                                  11337               11338  \
# Year of Birth                     2016                2016
# Gender                          FEMALE              FEMALE
# Ethnicity           BLACK NON HISPANIC  BLACK NON HISPANIC
# Child's First Name               Milan               Sanaa
# Count                               10                  10
#
#                                  11339               11340  \
# Year of Birth                     2016                2016
# Gender                          FEMALE              FEMALE
# Ethnicity           BLACK NON HISPANIC  BLACK NON HISPANIC
# Child's First Name               Sanai             Saniyah
# Count                               10                  10
#
#                                  11341               11342  \
# Year of Birth                     2016                2016
# Gender                          FEMALE              FEMALE
# Ethnicity           BLACK NON HISPANIC  BLACK NON HISPANIC
# Child's First Name                Skye               Tiana
# Count                               10                  10
#
#                                  11343               11344
# Year of Birth                     2016                2016
# Gender                          FEMALE              FEMALE
# Ethnicity           BLACK NON HISPANIC  BLACK NON HISPANIC
# Child's First Name              Violet               Zahra
# Count                               10                  10
#
# [5 rows x 11345 columns]

# %% [markdown]
# It can also be done using T attributes on the dataframe. df.T will do the same as df.transpose().

# %%
df_transposed = df.T
df_transposed.head()
# Out:
#                                          0                           1      \
# Year of Birth                             2011                        2011
# Gender                                  FEMALE                      FEMALE
# Ethnicity           ASIAN AND PACIFIC ISLANDER  ASIAN AND PACIFIC ISLANDER
# Child's First Name                      SOPHIA                       CHLOE
# Count                                      119                         106
#
#                                          2                           3      \
# Year of Birth                             2011                        2011
# Gender                                  FEMALE                      FEMALE
# Ethnicity           ASIAN AND PACIFIC ISLANDER  ASIAN AND PACIFIC ISLANDER
# Child's First Name                       EMILY                      OLIVIA
# Count                                       93                          89
#
#                                          4                           5      \
# Year of Birth                             2011                        2011
# Gender                                  FEMALE                      FEMALE
# Ethnicity           ASIAN AND PACIFIC ISLANDER  ASIAN AND PACIFIC ISLANDER
# Child's First Name                        EMMA                    ISABELLA
# Count                                       75                          67
#
#                                          6                           7      \
# Year of Birth                             2011                        2011
# Gender                                  FEMALE                      FEMALE
# Ethnicity           ASIAN AND PACIFIC ISLANDER  ASIAN AND PACIFIC ISLANDER
# Child's First Name                     TIFFANY                      ASHLEY
# Count                                       54                          52
#
#                                          8                           9      \
# Year of Birth                             2011                        2011
# Gender                                  FEMALE                      FEMALE
# Ethnicity           ASIAN AND PACIFIC ISLANDER  ASIAN AND PACIFIC ISLANDER
# Child's First Name                       FIONA                      ANGELA
# Count                                       48                          47
#
#                     ...               11335               11336  \
# Year of Birth       ...                2016                2016
# Gender              ...              FEMALE              FEMALE
# Ethnicity           ...  BLACK NON HISPANIC  BLACK NON HISPANIC
# Child's First Name  ...             Mikayla                Mila
# Count               ...                  10                  10
#
#                                  11337               11338  \
# Year of Birth                     2016                2016
# Gender                          FEMALE              FEMALE
# Ethnicity           BLACK NON HISPANIC  BLACK NON HISPANIC
# Child's First Name               Milan               Sanaa
# Count                               10                  10
#
#                                  11339               11340  \
# Year of Birth                     2016                2016
# Gender                          FEMALE              FEMALE
# Ethnicity           BLACK NON HISPANIC  BLACK NON HISPANIC
# Child's First Name               Sanai             Saniyah
# Count                               10                  10
#
#                                  11341               11342  \
# Year of Birth                     2016                2016
# Gender                          FEMALE              FEMALE
# Ethnicity           BLACK NON HISPANIC  BLACK NON HISPANIC
# Child's First Name                Skye               Tiana
# Count                               10                  10
#
#                                  11343               11344
# Year of Birth                     2016                2016
# Gender                          FEMALE              FEMALE
# Ethnicity           BLACK NON HISPANIC  BLACK NON HISPANIC
# Child's First Name              Violet               Zahra
# Count                               10                  10
#
# [5 rows x 11345 columns]

# %% [markdown]
# 18. df.merge()df.merge() is a pandas function that allows you to combine two DataFrames based on one or more common columns. It is similar to SQL JOINs. The function returns a new DataFrame that contains only the rows where the values in the specified columns match between the two DataFrames.
#
# Here is an example of how to use df.merge() to combine two DataFrames based on a common column:

# %%
# Create the first DataFrame
df1 = pd.DataFrame({'key': ['A', 'B', 'C', 'D'],
                   'value': [1, 2, 3, 4]})

# Create the second DataFrame
df2 = pd.DataFrame({'key': ['B', 'D', 'E', 'F'],
                   'value': [5, 6, 7, 8]})

# Merge the two DataFrames on the 'key' column
merged_df = df1.merge(df2, on='key')

# Print the merged DataFrame
print(merged_df)
# Out:
#   key  value_x  value_y
# 0   B        2        5
# 1   D        4        6

# %% [markdown]
# the default is seem to be inner join where there are no nan values.

# %%
# Merge the two DataFrames on the 'key' column
merged_df = df1.merge(df2, on='key',how='outer')

# %%
merged_df
# Out:
#   key  value_x  value_y
# 0   A      1.0      NaN
# 1   B      2.0      5.0
# 2   C      3.0      NaN
# 3   D      4.0      6.0
# 4   E      NaN      7.0
# 5   F      NaN      8.0

# %%
# Merge the two DataFrames on the 'key' column
merged_df = df1.merge(df2, on='key',how = 'left')

# %%
merged_df
# Out:
#   key  value_x  value_y
# 0   A        1      NaN
# 1   B        2      5.0
# 2   C        3      NaN
# 3   D        4      6.0

# %%
# Merge the two DataFrames on the 'key' column
merged_df = df1.merge(df2, on='key',how = 'right')

# %%
merged_df
# Out:
#   key  value_x  value_y
# 0   B      2.0        5
# 1   D      4.0        6
# 2   E      NaN        7
# 3   F      NaN        8

# %%
# Create the first DataFrame
df1 = pd.DataFrame({'key1': ['A', 'B', 'C', 'D'],
                   'value': [1, 2, 3, 4]})

# Create the second DataFrame
df2 = pd.DataFrame({'key2': ['B', 'D', 'E', 'F'],
                   'value': [5, 6, 7, 8]})

# %%
merged_df = df1.merge(df2, left_on='key1', right_on='key2',how='inner')

# %%
merged_df
# Out:
#   key1  value_x key2  value_y
# 0    B        2    B        5
# 1    D        4    D        6

# %% [markdown]
# 19. df.rename()df.rename() is a pandas function that allows you to change the name of one or more columns or rows in a DataFrame. You can use the columns parameter to change the column names, and the index parameter to change the row names.

# %%
# Rename column 'Count' to 'count'
df_rename = df.rename(columns={'Count': 'count'})
df_rename.head()
# Out:
#    Year of Birth  Gender                   Ethnicity Child's First Name  \
# 0           2011  FEMALE  ASIAN AND PACIFIC ISLANDER             SOPHIA
# 1           2011  FEMALE  ASIAN AND PACIFIC ISLANDER              CHLOE
# 2           2011  FEMALE  ASIAN AND PACIFIC ISLANDER              EMILY
# 3           2011  FEMALE  ASIAN AND PACIFIC ISLANDER             OLIVIA
# 4           2011  FEMALE  ASIAN AND PACIFIC ISLANDER               EMMA
#
#    count  Rank
# 0    119     1
# 1    106     2
# 2     93     3
# 3     89     4
# 4     75     5

# %%
df_rename = df.rename(columns={'Count': 'count', 'Rank':'rank'})
df_rename.head()
# Out:
#    Year of Birth  Gender                   Ethnicity Child's First Name  \
# 0           2011  FEMALE  ASIAN AND PACIFIC ISLANDER             SOPHIA
# 1           2011  FEMALE  ASIAN AND PACIFIC ISLANDER              CHLOE
# 2           2011  FEMALE  ASIAN AND PACIFIC ISLANDER              EMILY
# 3           2011  FEMALE  ASIAN AND PACIFIC ISLANDER             OLIVIA
# 4           2011  FEMALE  ASIAN AND PACIFIC ISLANDER               EMMA
#
#    count  rank
# 0    119     1
# 1    106     2
# 2     93     3
# 3     89     4
# 4     75     5

# %%
df_rename = df.rename(index={0:'first',1:'second',2:'third',20:'twenty'})
df_rename.head()
# Out:
#         Year of Birth  Gender                   Ethnicity Child's First Name  \
# first            2011  FEMALE  ASIAN AND PACIFIC ISLANDER             SOPHIA
# second           2011  FEMALE  ASIAN AND PACIFIC ISLANDER              CHLOE
# third            2011  FEMALE  ASIAN AND PACIFIC ISLANDER              EMILY
# 3                2011  FEMALE  ASIAN AND PACIFIC ISLANDER             OLIVIA
# 4                2011  FEMALE  ASIAN AND PACIFIC ISLANDER               EMMA
#
#         Count  Rank
# first     119     1
# second    106     2
# third      93     3
# 3          89     4
# 4          75     5

# %% [markdown]
# 20. df.to_csv()
# df.to_csv() is a method used in the Pandas library to export a DataFrame to a CSV file. CSV stands for "Comma Separated Values" and it is a popular file format for storing data in a tabular form.
#
# For example, let’s say we want to save df that you want to export to a CSV file. You can export the DataFrame to a CSV file by calling df.to_csv() and passing the file name as a string:

# %%
df.to_csv('C:/Users/Admin/pandas/data.csv')

# %% [markdown]
# You can also specify the separator used in the CSV file by passing the sep parameter. By default, it’s set to “,”.

# %%
df.to_csv('C:/Users/Admin/pandas/data2.csv', sep='\t')

# %% [markdown]
# #df.to_csv('path/to/data.csv', columns=['Rank','Count'])
# df.to_csv('path/to/data.csv', index=False)

# %% [markdown]
# You can also use na_rep parameter to replace missing values in the exported CSV file with a specific value.

# %% [markdown]
# df.to_csv('path/to/data.csv', na_rep='NULL')

# %% [markdown]
# # Loc is label base index and Iloc is integer base index.
